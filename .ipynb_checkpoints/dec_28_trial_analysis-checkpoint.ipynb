# %%
# import csv
import seaborn as sns
import numpy as np
import pandas as pd

import json
import matplotlib.pyplot as plt

from importlib import reload

import drawing as dw
reload(dw)
# Out:
# <module 'drawing' from '/home/xiaoyuz1/amazon_turk/drawing.py'>

# %%
fname = '/raid/xiaoyuz1/amazon_turk/2021_pilot/Batch_4637975_batch_results.csv'
df = pd.read_csv(fname)

# %%
sns.displot(df, x="WorkTimeInSeconds", bins=20)

# %%
df.columns
# Out:
# Index(['HITId', 'HITTypeId', 'Title', 'Description', 'Keywords', 'Reward',
#        'CreationTime', 'MaxAssignments', 'RequesterAnnotation',
#        'AssignmentDurationInSeconds', 'AutoApprovalDelayInSeconds',
#        'Expiration', 'NumberOfSimilarHITs', 'LifetimeInSeconds',
#        'AssignmentId', 'WorkerId', 'AssignmentStatus', 'AcceptTime',
#        'SubmitTime', 'AutoApprovalTime', 'ApprovalTime', 'RejectionTime',
#        'RequesterFeedback', 'WorkTimeInSeconds', 'LifetimeApprovalRate',
#        'Last30DaysApprovalRate', 'Last7DaysApprovalRate', 'Input.PROMPT01',
#        'Input.PROMPT02', 'Answer.canvasJsonOneStepName_0__0',
#        'Answer.canvasJsonOneStepName_0__1',
#        'Answer.canvasJsonOneStepName_0__2',
#        'Answer.canvasJsonOneStepName_0__3',
#        'Answer.canvasJsonOneStepName_0__4',
#        'Answer.canvasJsonOneStepName_1__0',
#        'Answer.canvasJsonOneStepName_1__1',
#        'Answer.canvasJsonOneStepName_1__10',
#        'Answer.canvasJsonOneStepName_1__11',
#        'Answer.canvasJsonOneStepName_1__2',
#        'Answer.canvasJsonOneStepName_1__3',
#        'Answer.canvasJsonOneStepName_1__4',
#        'Answer.canvasJsonOneStepName_1__5',
#        'Answer.canvasJsonOneStepName_1__6',
#        'Answer.canvasJsonOneStepName_1__7',
#        'Answer.canvasJsonOneStepName_1__8',
#        'Answer.canvasJsonOneStepName_1__9',
#        'Answer.canvasJsonOneStepName_2__0',
#        'Answer.canvasJsonOneStepName_2__1',
#        'Answer.canvasJsonOneStepName_2__10',
#        'Answer.canvasJsonOneStepName_2__11',
#        'Answer.canvasJsonOneStepName_2__12',
#        'Answer.canvasJsonOneStepName_2__2',
#        'Answer.canvasJsonOneStepName_2__3',
#        'Answer.canvasJsonOneStepName_2__4',
#        'Answer.canvasJsonOneStepName_2__5',
#        'Answer.canvasJsonOneStepName_2__6',
#        'Answer.canvasJsonOneStepName_2__7',
#        'Answer.canvasJsonOneStepName_2__8',
#        'Answer.canvasJsonOneStepName_2__9', 'Answer.feedback',
#        'Answer.stepAnnotationInput_0', 'Answer.stepAnnotationInput_1',
#        'Answer.stepAnnotationInput_2', 'Approve', 'Reject'],
#       dtype='object')

# %%
obj = dw.Drawing(df)

# %%
obj.draw_all()

# %%
obj.draw(30)
