# %%
import seaborn as sns
import numpy as np
import pandas as pd
import os
import json
import matplotlib.pyplot as plt
import PIL

import read_datasets as rd
import constants as CONST
from importlib import reload
reload(rd)
reload(CONST)

import base64
import string
import pickle
import spacy
import collections
import itertools, collections

from scipy.spatial import distance

# %%
pd.options.display.max_rows = 500

# %%
import finetune
reload(finetune)
from finetune import *

# %%
# feature_folder_template = "/raid/xiaoyuz1/sketch_datasets/face_features_weight_5/clip/{}"
# face_feature_dict = rd.get_features(feature_folder_template, list(CONST.face_part_image_indices.keys()))

# feature_folder_template = "/raid/xiaoyuz1/sketch_datasets/angel_features_weight_5/clip/{}"
# angel_feature_dict = rd.get_features(feature_folder_template, list(CONST.angel_part_image_indices.keys()))

# %%
# count = 0
# GPUS = ["2","3","5"]
# for f in os.listdir('/raid/xiaoyuz1/clip_model_checkpoint'):
#     if f.endswith(".pt"):
#         full_path = os.path.join('/raid/xiaoyuz1/clip_model_checkpoint' ,f)
#         full_save_path = full_path.replace("pt", "pickle")
#         print("\n")
#         print("python clip_finetune.py --test --GPU {} --test_model_path {} --test_save_path {}".format(
#             GPUS[count % 3], full_path, full_save_path))
#         count += 1

# %%
# dfn = new_df_pair()
dfo = pd.read_csv('/raid/xiaoyuz1/amazon_turk/df_all.csv')
dfo['no_punc_1'] = dfo.no_punc_1.apply(lambda x: [str(y).strip()[1:-1] for y in x[1:-1].split(',')])
# dfn = new_df_pair()
dfp = pd.read_csv('/raid/xiaoyuz1/amazon_turk/df_all_pair.csv')
dfp['no_punc_1'] = dfp.no_punc_1.apply(lambda x: [str(y).strip()[1:-1] for y in x[1:-1].split(',')])
dfp['no_punc_2'] = dfp.no_punc_2.apply(lambda x: [str(y).strip()[1:-1] for y in x[1:-1].split(',')])

# %% [markdown]
# # Load models

# %%
import nltk
nltk.download('wordnet')

from nltk.corpus import wordnet
from nltk.corpus import wordnet as wn
nltk.download('omw-1.4')
# Out:
# [nltk_data] Downloading package wordnet to /home/xiaoyuz1/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to /home/xiaoyuz1/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# True

# %%
import clip
import torch

# %%
# import open_clip

# %%
# nlp = spacy.load("en_core_web_sm")

# %%
filename = '/raid/xiaoyuz1/glove300_2word2vec_model.sav'
glovemodel = pickle.load(open(filename, 'rb'))

# %%
device = "cuda:6" if torch.cuda.is_available() else "cpu"

# %%
args = {}

# %%
root_folder = '/raid/xiaoyuz1/clip_model_checkpoint'
torch_path_name = os.path.join(root_folder, "pleasant-tree-10.pt")
checkpoint = torch.load(torch_path_name)
print(checkpoint.keys())
args = checkpoint['args']
# Out:
# dict_keys(['epoch', 'iteration', 'model_state_dict', 'optimizer_state_dict', 'loss', 'args'])

# %%
if 'open_clip' in args and args['open_clip']:
    model, train_transform, preprocess = \
        open_clip.create_model_and_transforms('ViT-B-32-quickgelu', \
                                              pretrained='laion400m_e32', device = device)    
else:
    model, preprocess = clip.load("ViT-B/32",device=device,jit=False) #Must set jit=False for training

# %%
model.load_state_dict(checkpoint['model_state_dict'])
# Out:
# <All keys matched successfully>

# %%
from transformers import BertTokenizer, BertModel
bert_tokenizer = BertTokenizer.from_pretrained('bert-base-uncased')
bert_model = BertModel.from_pretrained("bert-base-uncased")
bert_model = bert_model.to(device)
# Out:
# Some weights of the model checkpoint at bert-base-uncased were not used when initializing BertModel: ['cls.predictions.transform.dense.bias', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.transform.LayerNorm.bias', 'cls.predictions.transform.dense.weight', 'cls.predictions.decoder.weight', 'cls.seq_relationship.bias', 'cls.seq_relationship.weight', 'cls.predictions.bias']
# - This IS expected if you are initializing BertModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).

# %%
modelzs, _ = clip.load("ViT-B/32",device=device,jit=False)

# %%
root_folder = '/raid/xiaoyuz1/clip_model_checkpoint'
torch_path_name_face = os.path.join(root_folder, "fearless-salad-4.pt")
checkpoint_face = torch.load(torch_path_name_face)

args_face = checkpoint_face['args']

if 'open_clip' in args and args_face['open_clip']:
    model_face, _, preprocess_face = \
        open_clip.create_model_and_transforms('ViT-B-32-quickgelu', \
                                              pretrained='laion400m_e32', device = device)    
else:
    model_face, preprocess_face = clip.load("ViT-B/32", \
                                            device=device,jit=False) 
model_face.load_state_dict(checkpoint_face['model_state_dict'])
# Out:
# <All keys matched successfully>

# %% [markdown]
# # Single dfn

# %% [markdown]
# ### Process

# %%
dfs, selected_pairss, df_inputs, df_idx_to_task_idxs = \
    rd.compile_face_dfs()

# %%
dfo = rd.new_df(dfs, df_idx_to_task_idxs, skip=[0])
dfo.head()

# %%
escape_list = ["shaped", "shape", "and", "like", "sized"]

for i in range(1,2):
    i = str(i)
    dfo['tokenized_{}'.format(i)] = dfo['text_{}'.format(i)].apply(
        lambda x: [y.lemma_ for y in nlp(x) if y.text not in escape_list]
    )
    dfo['lower_{}'.format(i)] = dfo['tokenized_{}'.format(i)].apply(lambda x: [word.lower() for word in x])
    
    punc = string.punctuation
    dfo['no_punc_{}'.format(i)] = dfo['lower_{}'.format(i)].apply(
        lambda x: [word for word in x if word not in punc]
    )
    dfo['no_punc_str_{}'.format(i)] = [' '.join(map(str, l)) for l in dfo['no_punc_{}'.format(i)]]

# %%
dfo.to_csv('/raid/xiaoyuz1/amazon_turk/df_all.csv', index=False)

# %% [markdown]
# ### Preliminary analysis

# %%
def print_info(df):
    print("Total number of rows in dataframe:", len(df))
    print("\nNumber of rows for face: ", len(df[df['category'] == 'face']))
    facestr = []
    for k,v in CONST.face_parts_idx_dict.items():
        x = len(df[(df['category'] == 'face') & (df['part'] == k)])
        facestr.append(str(x))
        print("(face) #{} =".format(v), x)
    print(" & ".join(facestr))
    
    print("\nNumber of rows for angel: ", len(df[df['category'] == 'angel']))
    angelstr = []
    for k,v in CONST.angel_parts_idx_dict.items():
        x = len(df[(df['category'] == 'angel') & (df['part'] == k)])
        angelstr.append(str(x))
        print("(angel) #{} =".format(v), x)
    print(" & ".join(angelstr))
    
    print("\nNumber of unique workers:", len(df['worker_id'].unique()))

# %%
print_info(dfo)

# %%
def num_unique_words(df):
    corpus = list(df['no_punc_1'].to_numpy())
    corpus = list(itertools.chain.from_iterable(corpus))

    counter = collections.Counter(corpus)
    delete_list = []
    for k,v in counter.items():
        
        if k.strip() == '':
            delete_list += [k]
    for k in delete_list:
        del counter[k]
    return counter

# %%
facestr = []
for k,v in CONST.face_part_image_indices.items():
    x = num_unique_words(dfo[(dfo['category'] == 'face') & (dfo['part'] == k)])
    x = len(x)
    facestr.append(str(x))
print(" \t ".join(facestr))

angelstr = []
for k,v in CONST.angel_part_image_indices.items():
    x = num_unique_words(dfo[(dfo['category'] == 'angel') & (dfo['part'] == k)])
    x = len(x)
    angelstr.append(str(x))
print(" \t ".join(angelstr))
# Out:
# 227 	 358 	 323 	 152 	 313
# 363 	 112 	 21 	 87 	 378 	 423 	 532

# %%
sum([int(x) for x in angelstr])

# %%
def print_corpus_info(df, cat=None):
    if cat is None:
        dfcat = df
    else:
        dfcat = df[df['category'] == cat]
    corpus = list(dfcat['no_punc_1'].to_numpy())
    corpus = list(itertools.chain.from_iterable(corpus))

    counter = collections.Counter(corpus)
    print("Number of distinct words:", len(counter))
    most = counter.most_common()

    x, y= [], []
    for word,count in most[:100]:
        x.append(word)
        y.append(count)
    plt.figure(figsize=(20,20))
    print("Total count of top frequent words: ", sum(y))
    sns.barplot(x=y,y=x)

# %%
print_corpus_info(dfo)
# Out:
# Number of distinct words: 1452
# Total count of top frequent words:  16047

# %%
from wordcloud import WordCloud 
import requests

# %%
def word_cloud(df, topn = 100):
    dfcat = df.reset_index(drop=True)
    corpus = list(dfcat['no_punc_1'].to_numpy())
    corpus = list(itertools.chain.from_iterable(corpus))

    counter = collections.Counter(corpus)
    comment_words = " "
    most = counter.most_common()
    x, y= [], []
    for word,count in most[:topn]: 
        comment_words += " ".join([word])+" "

    wordcloud = WordCloud(width = 2000, height = 2000, 
                    background_color ='white',
                    min_font_size = 4).generate(comment_words)
    plt.figure(figsize = (5, 5), facecolor = 'white', edgecolor='blue') 
    plt.imshow(wordcloud) 
    plt.axis("off") 
    plt.tight_layout(pad = 0) 

    plt.show()
    #return comment_words
    return comment_words

# %%
sc = word_cloud(dfo)

# %%
counter = num_unique_words(dfo)
most = counter.most_common()

# %%
row = 10
for i in range(20):
    start = i * row
    end = (i+1) * row
    for j in range(start,end):
        print(most[j][0])
    print("\n")
# Out:
# small
# oval
# circular
# round
# wide
# open
# large
# curve
# triangular
# line
#
#
# long
# flat
# uneven
# u
# thin
# rounded
# narrow
# vertical
# straight
# tiny
#
#
# oblong
# short
# asymmetrical
# smile
# dot
# point
# rectangular
# big
# linear
# close
#
#
# circle
# tall
# curved
# horizontal
# sharp
# pointy
# egg
# top
# square
# trapezoidal
#
#
# lumpy
# l
# stick
# closed
# triangle
# angular
# c
# slanted
# dotted
# smooth
#
#
# ovoid
# jagged
# angle
# heart
# bottomed
# messy
# unconnected
# sideways
# lopsided
# half
#
#
# jag
# slightly
# broad
# rotate
# ring
# irregular
# crescent
# tilt
# skinny
# upright
#
#
# wavy
# single
# upturned
# v
# bottom
# curvy
# down
# finger
# curly
# pointing
#
#
# spiky
# symmetrical
# squiggly
# right
# happy
# upside
# upward
# fill
# flatten
# semi
#
#
# shallow
# ovular
# bumpy
# even
# incomplete
# medium
# with
# double
# hook
# face
#
#
# thick
# edge
# butterfly
# sided
# deep
# beaker
# arch
# moon
# crooked
# unsymmetrical
#
#
# boxy
# teardrop
# d
# disk
# parabolic
# feather
# bell
# beady
# bowl
# fat
#
#
# elongate
# j
# full
# orient
# three
# bean
# a
# lobed
# left
# slim
#
#
# trapezoid
# rectangle
# pear
# arrow
# low
# bent
# downward
# spiral
# fluffy
# pizza
#
#
# proportional
# hand
# backwards
# center
# scribble
# ball
# potato
# off
# diamond
# squarish
#
#
# horizontally
# empty
# ear
# trilateral
# in
# singular
# grin
# vertically
# diagonal
# bulbous
#
#
# set
# side
# leave
# angled
# inverted
# orb
# roundish
# disc
# serrate
# banana
#
#
# rough
# elliptical
# bow
# vast
# letter
# figure
# float
# slice
# leaf
# droopy
#
#
# unfinished
# lob
# ridged
# two
# turn
# smiley
# tear
# dash
# cloud
# spikey
#
#
# unclosed
# pointed
# blocky
# globe
# very
# feathery
# flame
# pinpoint
# one
# up

# %%
common_words = [x[0] for x in most[:200]]
with torch.no_grad():
    common_words_features = model.encode_text(torch.cat([clip.tokenize(common_words).to(device)]))
print(common_words_features.shape)
# Out:
# torch.Size([200, 512])

# %%
from sklearn.manifold import TSNE                   # final reduction

tsne_model2 = TSNE(perplexity=128, n_components=2, init='pca', n_iter=2500, random_state=23)
clip_values = tsne_model2.fit_transform(common_words_features.cpu().numpy())
# Out:
# /home/xiaoyuz1/anaconda3/envs/clipdraw/lib/python3.8/site-packages/sklearn/manifold/_t_sne.py:790: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   warnings.warn(
# /home/xiaoyuz1/anaconda3/envs/clipdraw/lib/python3.8/site-packages/sklearn/manifold/_t_sne.py:982: FutureWarning: The PCA initialization in TSNE will change to have the standard deviation of PC1 equal to 1e-4 in 1.2. This will ensure better convergence.
#   warnings.warn(

# %%
x = []
y = []
for value in clip_values:
    x.append(value[0])
    y.append(value[1])

plt.figure(figsize=(20,10))
for i in range(len(x)):
    plt.scatter(x[i],y[i],alpha=0.4)
    plt.annotate(common_words[i],
                 xy=(x[i], y[i]),
                 xytext=(5, 2),
                 textcoords='offset points',
                 ha='right',
                 va='bottom',
                 fontsize=10,
                )
plt.axis("off") 
plt.show()

# %% [markdown]
# # Pair dfn

# %%
dfs, selected_pairss, df_inputs, df_idx_to_task_idxs = \
    rd.compile_face_dfs()

dfn = rd.new_df_pair(dfs, df_idx_to_task_idxs, skip=[0])
dfn.head()

# %%
escape_list = ["shaped", "shape", "and", "like", "sized"]

for i in range(1,3):
    i = str(i)
    dfn['tokenized_{}'.format(i)] = dfn['text_{}'.format(i)].apply(
        lambda x: [y.lemma_ for y in nlp(x) if y.text not in escape_list]
    )
    dfn['lower_{}'.format(i)] = dfn['tokenized_{}'.format(i)].apply(lambda x: [word.lower() for word in x])
    punc = string.punctuation
    dfn['no_punc_{}'.format(i)] = dfn['lower_{}'.format(i)].apply(
        lambda x: [word for word in x if word not in punc]
    )
    dfn['no_punc_str_{}'.format(i)] = [' '.join(map(str, l)) for l in dfn['no_punc_{}'.format(i)]]

# %%
dfn.to_csv('/raid/xiaoyuz1/amazon_turk/df_all_pair.csv', index=False)

# %%
print_info(dfp)

# %%
facestr = []
for k,v in CONST.face_part_image_indices.items():
    x = len(v)
    facestr.append(str(x))
print(" & ".join(facestr))

angelstr = []
for k,v in CONST.angel_part_image_indices.items():
    x = len(v)
    angelstr.append(str(x))
print(" & ".join(angelstr))

# %%
for row_idx in dfp[dfp['category'] == 'face'].index:
    row = dfp.iloc[row_idx]
    
    p1,p2 = row['image_1'], row['image_2']
    part_idx = row['part']

    w1 = row['no_punc_str_1']
    w2 = row['no_punc_str_2']
    ws = [w1,w2]
    plt.figure(figsize=(10,5))
    for i,p in enumerate([p1,p2]):
        img = PIL.Image.open('/raid/xiaoyuz1/sketch_datasets/face_images_weight_5_all/{}.png'.format(p))
        plt.subplot(1,2,i+1)
        img = img.convert(mode='RGB')
        plt.imshow(img)
        plt.title("{} {}".format(ws[i], CONST.face_parts_idx_dict[part_idx]))
    plt.savefig('/raid/xiaoyuz1/amazon_turk/results/{}.png'.format(str(row_idx)))

# %%
dfo[dfo['category'] == 'angel']
# Out:
#        image_1       worker_id  part category   time  \
# 5030       202  A3KP8KFGG6734Q     7    angel  656.2
# 5031       213  A3KP8KFGG6734Q     7    angel  656.2
# 5032       489  A3KP8KFGG6734Q     5    angel  656.2
# 5033       639  A3KP8KFGG6734Q     5    angel  656.2
# 5034        24  A3KP8KFGG6734Q     4    angel  656.2
# ...        ...             ...   ...      ...    ...
# 11145      280   APGX2WZ59OWDN     5    angel  239.0
# 11146      736   APGX2WZ59OWDN     7    angel  239.0
# 11147      477   APGX2WZ59OWDN     7    angel  239.0
# 11148      614   APGX2WZ59OWDN     4    angel  239.0
# 11149      693   APGX2WZ59OWDN     4    angel  239.0
#
#                                                 folder            text_1  \
# 5030     /raid/xiaoyuz1/amazon_turk/2022_04_05_release          Triangle
# 5031     /raid/xiaoyuz1/amazon_turk/2022_04_05_release      sharp pointy
# 5032     /raid/xiaoyuz1/amazon_turk/2022_04_05_release          triangle
# 5033     /raid/xiaoyuz1/amazon_turk/2022_04_05_release         long oval
# 5034     /raid/xiaoyuz1/amazon_turk/2022_04_05_release      small circle
# ...                                                ...               ...
# 11145  /raid/xiaoyuz1/amazon_turk/2022_04_06_release_3          serrated
# 11146  /raid/xiaoyuz1/amazon_turk/2022_04_06_release_3  butterfly-shaped
# 11147  /raid/xiaoyuz1/amazon_turk/2022_04_06_release_3             bumpy
# 11148  /raid/xiaoyuz1/amazon_turk/2022_04_06_release_3       rectangular
# 11149  /raid/xiaoyuz1/amazon_turk/2022_04_06_release_3            tilted
#
#                tokenized_1              lower_1        no_punc_1 no_punc_str_1
# 5030          ['Triangle']         ['triangle']       [triangle]      triangle
# 5031   ['sharp', 'pointy']  ['sharp', 'pointy']  [sharp, pointy]  sharp pointy
# 5032          ['triangle']         ['triangle']       [triangle]      triangle
# 5033      ['long', 'oval']     ['long', 'oval']     [long, oval]     long oval
# 5034   ['small', 'circle']  ['small', 'circle']  [small, circle]  small circle
# ...                    ...                  ...              ...           ...
# 11145          ['serrate']          ['serrate']        [serrate]       serrate
# 11146   ['butterfly', '-']   ['butterfly', '-']      [butterfly]     butterfly
# 11147            ['bumpy']            ['bumpy']          [bumpy]         bumpy
# 11148      ['rectangular']      ['rectangular']    [rectangular]   rectangular
# 11149             ['tilt']             ['tilt']           [tilt]          tilt
#
# [6120 rows x 11 columns]

# %% [markdown]
# # (Section)

# %% [markdown]
# ## get all annotations for a given `(image,part)`

# %%
def get_pair_data(dfn, part_idx_list):
    all_image_indices = np.unique(list(dfn['image_1'].to_numpy()) + list(dfn['image_2'].to_numpy()))
    
    compare_pair = collections.defaultdict(list)
    
    for image_idx in all_image_indices:
        for part_idx in part_idx_list:

            l = []

            dfn_i = dfn[(dfn['part'] == part_idx) & (dfn['image_1'] == image_idx)]
            for i in dfn_i.index:
                row = dfn.iloc[i]

                w1 = row['no_punc_str_1']
                w2 = row['no_punc_str_2']

                l.append((i, row['image_2'], w1,w2))

            dfn_i = dfn[(dfn['part'] == part_idx) & (dfn['image_2'] == image_idx)]
            for i in dfn_i.index:
                row = dfn.iloc[i]

                w1 = row['no_punc_str_1']
                w2 = row['no_punc_str_2']

                l.append((i, row['image_1'], w2,w1))

            if len(l) > 1:
                compare_pair[(image_idx,part_idx)] += l
    return compare_pair

# %%
dfp_face = dfp[dfp['category'] == 'face']
dfp_face = dfp_face.reset_index(drop=True)
compare_pair_face = get_pair_data(dfp_face, CONST.parts_idx_dict.keys())

# %%
print(len(compare_pair_face), 572+572+334+104+572)

# %%
dfp_angel = dfp[dfp['category'] == 'angel']
dfp_angel = dfp_angel.reset_index(drop=True)
compare_pair_angel = get_pair_data(dfp_angel, CONST.angel_parts_idx_dict.keys())

# %%
print(len(compare_pair_angel),779+ 781 +732 + 558 + 80 + 114 + 8)

# %% [markdown]
# ## opposite annotations

# %%
def get_syn_ant(w):
    synonyms = []
    antonyms = []

    for syn in wordnet.synsets(w):
        for l in syn.lemmas():
            synonyms.append(l.name())
            if l.antonyms():
                antonyms.append(l.antonyms()[0].name())
    return list(set(synonyms)), list(set(antonyms))


wl_list = set()
# for obj, count in all_pair_counter.most_common():
for obj in ks_sorted[::-1][:150]:
    L = np.asarray(all_pair_dict[obj])
    s1,a1 = get_syn_ant(obj.x)
    s2,a2 = get_syn_ant(obj.y)
    for w in a1:
        wl_list.add((obj.x,w))
    for w in a2:
        if "_" in w:
            for wi in w.split("_"):
                wl_list.add((obj.y,wi))
        wl_list.add((obj.y,w))

wl_list = [Pair(p) for p in wl_list]
wl_list = collections.Counter(wl_list)

# %%
problem = []

# %%
for k,v in compare_pair.items():
    w1s = []
    w2s = []
    for _,_,w1,w2 in v:
        w1s += w1.split(" ")
        w2s += w2.split(" ")
    w1s = list(set(w1s))
    add = False
    for wl in wl_list:
        all_in = True
        for w in [wl.x, wl.y]:
            if w not in w1s:
                all_in = False
        if all_in:
            problem.append((k, (wl.x,wl.y)))

# %%
problem_unique = list(set([(p1,part_idx) for (p1,part_idx),wl in problem]))
print(len(problem_unique))

# %%
for (p1,part_idx),wl in problem:
    print("\n\n",p1,rd.part_idx_to_words[part_idx],wl)
    for _,p2,w1,w2 in compare_pair[(p1,part_idx)]:
        ws = [w1,w2]
        plt.figure(figsize=(10,5))
        for i,p in enumerate([p1, p2]):
            img = PIL.Image.open(
            '/raid/xiaoyuz1/sketch_datasets/face_images_weight_5_all/{}.png'.format(p))
            plt.subplot(1,2,i+1);
            img = img.convert(mode='RGB')
            plt.imshow(img)
            plt.title("{} {}".format(ws[i], rd.part_idx_to_words[part_idx]))
        plt.show()

# %% [markdown]
# ## synonym according to synset and GloVE

# %%
c = num_unique_words(dfo)

# %%
with open("/raid/xiaoyuz1/amazon_turk/unique_words.pickle", "wb+") as f:
    pickle.dump(c, f)

# %%
wn.synsets('small',pos=wn.ADJ)
# Out:
# [Synset('small.a.01'),
#  Synset('minor.s.10'),
#  Synset('little.s.03'),
#  Synset('small.s.04'),
#  Synset('humble.s.01'),
#  Synset('little.s.07'),
#  Synset('little.s.05'),
#  Synset('small.s.08'),
#  Synset('modest.s.02'),
#  Synset('belittled.s.01')]

# %%
wn.synsets('big')[1].path_similarity(wn.synsets('small',pos=wn.ADJ)[0])
# Out:
# 0.3333333333333333

# %%
glovemodel.similarity("linear", "open")
# Out:
# 0.2722421

# %%
synset_info = []
for k,v in c.items():
    synset_info.append(len(wn.synsets(k)))

# %%
print(len(not_in_synset))
# Out:
# 182

# %%
np.asarray(list(c.keys()))[np.asarray(synset_info) == 0]
# Out:
# array(['shorty', 'spikey', 'pointy', 'smirky', 'swirly', 'circulur',
#        'slitte', 'unclosed', 'ovoloid', 'zagged', 'oblongated', 'with',
#        'veritcal', 'the', 'squiggled', 'teethless', 'pupile', 'bosy',
#        'rightward', 'leftward', 'dotlike', 'hatlike', 'poofy', 'drapy',
#        'elatedly', 'spkey', 'lopside', 'unshade', 'snuby', 'pupilless',
#        'sahpe', 'than', 'bente', 'lindear', 'downturne', 'recangular',
#        'uncentere', ' ', 'slitted', 'to', 'rectuangular', 'squircle',
#        'ovalish', 'assymmetrical', 'semioval', 'of', 'anglular',
#        'checkmark', 'ovaloid', 'ovaltine', 'dumple', 'oble',
#        'superellipse', 'reuleaux', 'pinpricke', 'masklike', 'multi',
#        'stright', 'similing', 'scribbly', 'bullseye', 'pupille', '  ',
#        'unsmile', 'frowny', 'triangularly', 'cartoonishly',
#        'microminiature', 'snaggle', 'toothe', 'monolid', 'browe',
#        'verticall', 'heptagonal', 'downbend', 'whirly', 'jaggedy',
#        'eliptical', 'cirlular', 'trapeziodal', 'grapefuit', 'trapizem',
#        'trapezodial', 'staright', 'earre', 'traingular', 'irregualr',
#        'triangluar', 'rectangualar', 'tirangular', 'ballon', 'unamuse',
#        'pronge', 'pointlike', 'spherish', 'linned', 'thinline',
#        'asymmetical', 'misshape', 'triagonal', 'sheild', 'triangularv',
#        'circlular', 'slend', 'sawblade', 'hooplike', 'unibrow', 'anguar',
#        'blurringly', 'cirucular', 'hearted', 's-', 'evne', 'hortizontal',
#        'birdlike', 'outstretche', 'triangule', 'attatche', 'cirular',
#        'nubbe', 'cee', 'dee', 'cicle', 'circleshape', 'smalll', 'firey',
#        'isoscele', 'batlike', 'smalloval', 'double-', 'batwe', 'shapedd',
#        'hockeystick', 'trapzoid', 'trapazoid', 'saggy', 'ovoidal',
#        'proportianate', 'jellybean', 'limbe', 'cathead', 'sitck',
#        'triagular', 'butterflylike', 'undetailed', 'oviod', "hershey's",
#        'ovalular', 'monocular', 'pacman', 'angelwise', 'shap',
#        'tringular', 'largr', 'riceball', 'tri', 'retangular', 'flat2',
#        'overline', 'flamelike', 'stemlike', 'trapizodal', 'seperate',
#        'cylindar', 'butterly', 'shappe', 'assymetrical', 'striaght',
#        'cornererd', 'lng', 'baloon', 'cheste', 'rought', 'guitarpick',
#        'cheeto', 'dorito', 'infundibular', 'outstreched', 'fluffily',
#        'notchless', 'tanktop', 'circuluar'], dtype='<U16')

# %%
np.sum(np.asarray([y for (x,y) in c.most_common()]) <= 1)
# Out:
# 650

# %% [markdown]
# # Create Splits

# %%
import random
def split_list(L):
    L.sort()  
    random.seed(1028)
    random.shuffle(L) 

    split_1 = int(0.7 * len(L))
    split_2 = int(0.8 * len(L))
    train_L = L[:split_1]
    dev_L = L[split_1:split_2]
    test_L = L[split_2:]
    return train_L,dev_L,test_L

def add_split(df):
    all_split = ["train"] * len(df)
    
    for cat,parts_idx_dict in [('face', CONST.face_parts_idx_dict), ('angel', CONST.angel_parts_idx_dict)]:
    
        for k in parts_idx_dict.keys():
            df_part = df[(df['category'] == cat) & (df['part'] == k)]
            df_indices = df_part.index.tolist()
            tr,de,te = split_list(df_indices)
            for i in tr:
                all_split[i] = "train"
            for i in de:
                all_split[i] = "dev"
            for i in te:
                all_split[i] = "test"
    
    df['split'] = all_split
    return df

# %%
def print_split_info(df):
    
    for s in ['train','dev','test']:
        split_num = len(df[(df['split'] == s)])
        print("all {}: total={}, perc={:.2f}".format(s,split_num,split_num/len(df)))
    
    for cat in ['face','angel']:
        print("\n")
        total = len(df[(df['category'] == cat)])
        for s in ['train','dev','test']:
            split_num = len(df[(df['category'] == cat) & (df['split'] == s)])
            print("{} {}: total={}, perc={:.2f}".format(cat,s,split_num,split_num/total))

# %%
dfo = add_split(dfo)

# %%
print_split_info(dfo)

# %%
dfp = add_split(dfp)
print_split_info(dfp)

# %%
dfp.to_csv('/raid/xiaoyuz1/amazon_turk/df_all_pair_withsplit.csv', index=False)

# %% [markdown]
# # CLIP Classification Table

# %% [markdown]
# ### load clip

# %%
for k,v in model.state_dict().items():
    if (k.startswith("visual.transformer") or k.startswith("visual")):
        print(k, v.shape)

# %%
# import torch
# for partial_path in os.listdir(root_folder):
#     if partial_path.endswith(".pickle"):
#         acc_path_name = os.path.join(root_folder ,partial_path)
#         torch_path_name = acc_path_name.replace("pickle","pt")
#         if not os.path.exists(torch_path_name):
#             continue
        
#         checkpoint = torch.load(torch_path_name)
#         args = checkpoint['args']
        
#         with open(acc_path_name, 'rb') as f:
#             _, final_accs, preds, gts = pickle.load(f)
#             with open(acc_path_name, 'wb+') as fw:
#                 pickle.dump((args['TRAIN_CATEGORY'], final_accs, preds, gts), fw)

# %% [markdown]
# ### fine-tuning results compiled

# %%
root_folder = '/raid/xiaoyuz1/clip_model_checkpoint'

data = {
    'name' : [],
    'train_cat' : [],
    'face_test' : [],
    'angel_test' : [],
    'face_dev' : [],
    'angel_dev' : [],
    'train' : [],
}

for partial_path in os.listdir(root_folder):
    if partial_path.endswith(".pickle"):
        acc_path_name = os.path.join(root_folder ,partial_path)
        torch_path_name = acc_path_name.replace("pickle", "pt")
        if not os.path.exists(torch_path_name):
            continue
        
        with open(acc_path_name, 'rb') as f:
            train_cat, final_accs, _, _ = pickle.load(f)
            try:
                data['face_test'].append(final_accs['test']['face'])
                data['angel_test'].append(final_accs['test']['angel'])
                data['face_dev'].append(final_accs['dev']['face'])
                data['angel_dev'].append(final_accs['dev']['angel'])
                data['train'].append(final_accs['train'])
                data['name'].append(partial_path.split(".")[0])
                
                data['train_cat'].append(" ".join(train_cat))
                
            except:
                print(partial_path)

dfacc = pd.DataFrame.from_dict(data)

# %%
dfacc[dfacc.train_cat.apply(lambda x: (x == "face angel"))].sort_values(
    by=['angel_test'],ascending=False)
# Out:
#                    name   train_cat  face_test  angel_test  face_dev  \
# 17    exalted-breeze-19  face angel   0.725296    0.721498  0.717131
# 4    fiery-butterfly-21  face angel   0.722332    0.710098  0.699203
# 16     pleasant-tree-10  face angel   0.743083    0.703583  0.717131
# 10  eternal-aardvark-20  face angel   0.711462    0.698697  0.693227
# 6       snowy-dawn-11_2  face angel   0.708498    0.678339  0.683267
# 5         snowy-dawn-11  face angel   0.714427    0.673453  0.701195
# 2       atomic-meadow-1  face angel   0.627470    0.623779  0.623506
#
#     angel_dev     train
# 17   0.708469  0.915063
# 4    0.716612  0.856685
# 16   0.710098  0.928406
# 10   0.724756  0.939441
# 6    0.685668  0.871055
# 5    0.693811  0.800616
# 2    0.620521  0.649602

# %%
dfacc[dfacc.train_cat.apply(lambda x: x == "face")].sort_values(
    by=['angel_dev'],ascending=False)
# Out:
#                    name train_cat  face_test  angel_test  face_dev  angel_dev  \
# 15      whole-surf-12_2      face   0.662055    0.584691  0.687251   0.581433
# 0         giddy-field-6      face   0.671937    0.591205  0.673307   0.578176
# 14     fearless-salad-4      face   0.700593    0.580619  0.685259   0.574919
# 12         woven-lake-9      face   0.596838    0.572476  0.615538   0.570033
# 1   resilient-puddle-23      face   0.671937    0.583062  0.699203   0.568404
# 8   pleasant-blaze-16_2      face   0.648221    0.576547  0.689243   0.566775
# 13    pleasant-blaze-16      face   0.667984    0.574919  0.695219   0.565147
# 7         happy-wind-24      face   0.712451    0.573290  0.715139   0.563518
# 11      jumping-dawn-31      face   0.694664    0.586319  0.733068   0.547231
# 9         easy-brook-22      face   0.704545    0.577362  0.703187   0.542345
#
#        train
# 15  0.744312
# 0   0.773322
# 14  0.834755
# 12  0.617179
# 1   0.780432
# 8   0.724972
# 13  0.751991
# 7   0.837031
# 11  0.996587
# 9   0.943686

# %%
dfacc[dfacc.train_cat.apply(lambda x: x == "angel")].sort_values(
    by=['face_dev'],ascending=False)
# Out:
#                name train_cat  face_test  angel_test  face_dev  angel_dev  \
# 3  visionary-sun-30     angel   0.581028    0.671824  0.609562   0.705212
#
#       train
# 3  0.942029

# %% [markdown]
# ### word embeddings and cosine similarity

# %%
dfp = get_df()
template_1,template_2 = template[0]
dfp['caption_1'] = dfp.apply(template_1, axis=1)
dfp['caption_2'] = dfp.apply(template_2, axis=1)

# %%
c = None
with open("/raid/xiaoyuz1/amazon_turk/unique_words.pickle", "rb") as f:
    c = pickle.load(f)

# %%
save_root = "/raid/xiaoyuz1/amazon_turk/word_embeddings"

# %%
word_feat = calculate_word_embeddings(
    list(c.keys()), \
    glovemodel, \
    device, \
    tokenizer = None, \
    path = os.path.join(save_root, "glove.pickle"), \
    save_to_path = True, \
    model_type = "glove",
)
# Out:
# Extracting word embeddings using Glove Gensim

# %%
word_feat = calculate_word_embeddings(
    list(c.keys()), \
    model, \
    device, \
    tokenizer = None, \
    path = os.path.join(save_root, "zs.pickle"), \
    save_to_path = True, \
    model_type = "clip"
)
# Out:
# Extracting word embeddings using CLIP

# %%
word_feat = calculate_word_embeddings(
    list(c.keys()), \
    model, \
    device, \
    tokenizer = None, \
    path = os.path.join(save_root, "pleasant-tree-10.pickle"), \
    save_to_path = True, \
    model_type = "clip"
)
# Out:
# Extracting word embeddings using CLIP

# %%
word_feat = calculate_word_embeddings(
    list(c.keys()), \
    bert_model, \
    device, \
    tokenizer = bert_tokenizer, \
    path = os.path.join(save_root, "bert.pickle"), \
    save_to_path = True, \
    model_type = "bert"
)
# Out:
# Extracting word embeddings using bert

# %%
class WordEmb:
    def __init__(self, wordlist, sim):
        self.wordlist = list(wordlist)
        self.sim = torch.tensor(sim)
    
    def similarity(self, w1, w2):
        if w1 not in self.wordlist:
            raise ValueError("{} is not in the word list!".format(w1))
        if w2 not in self.wordlist:
            raise ValueError("{} is not in the word list!".format(w2))
        i = self.wordlist.index(w1)
        j = self.wordlist.index(w2)
        return self.sim[i][j].item()
    
    def most_similar(self, w, topn=10, different=False):
        if w not in self.wordlist:
            raise ValueError("{} is not in the word list!".format(w))

        i = self.wordlist.index(w)
        row = self.sim[i]
        if different:
            top_indices = torch.argsort(row)[:topn]
        else:
            top_indices = torch.argsort(row)[-(topn+1):-1]
            top_indices = list(top_indices)[::-1]

        top_list = zip(
            [self.wordlist[j] for j in top_indices],
            [row[j].item() for j in top_indices],
        )
        return list(top_list)

# %%
obj = WordEmb(wordlist, sim)
# Out:
# <ipython-input-107-d90226dc5c01>:4: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   self.sim = torch.tensor(sim)

# %%
wordlist.index("circular"),wordlist.index("egg")
# Out:
# (11, 113)

# %%
sim[11][113],sim[113][11]
# Out:
# (tensor(0.7329, dtype=torch.float16), tensor(0.7329, dtype=torch.float16))

# %%
sim[11].mean()
# Out:
# tensor(0.7104, dtype=torch.float16)

# %% [markdown]
# ### distance

# %% [markdown]
# #### contrastive word pairs

# %%
all_pair_df = pd.read_csv('/raid/xiaoyuz1/amazon_turk/df_all_pair_word_pairs.csv')

# %%
all_pair_df = calculate_word_similarity_clip(
    all_pair_df, model_face, device, column_name = "sim_clip_face", cosine_sim = False)
all_pair_df = calculate_word_similarity_clip(
    all_pair_df, model, device, column_name = "sim_clip_face_angel", cosine_sim = False)
all_pair_df = calculate_word_similarity_bert(
    all_pair_df, bert_model, bert_tokenizer, device, \
    column_name = "sim_bert", cosine_sim = False)
all_pair_df = calculate_word_similarity_glove(
    all_pair_df, glovemodel, device, \
    column_name = "sim_glove", cosine_sim = False)

# %%
all_pair_df = calculate_word_similarity_clip(
    all_pair_df, modelzs, device, column_name = "cosine_sim_clip", cosine_sim = True)

# %%
all_pair_df = calculate_word_similarity_clip(
    all_pair_df, model_face, device, column_name = "cosine_sim_clip_face", cosine_sim = True)
all_pair_df = calculate_word_similarity_clip(
    all_pair_df, model, device, column_name = "cosine_sim_clip_face_angel", cosine_sim = True)
all_pair_df = calculate_word_similarity_bert(
    all_pair_df, bert_model, bert_tokenizer, device, \
    column_name = "cosine_sim_bert", cosine_sim = True)
all_pair_df = calculate_word_similarity_glove(
    all_pair_df, glovemodel, device, \
    column_name = "cosine_sim_glove", cosine_sim = True)

# %%
print(all_pair_df.columns)
cols = ['word1', 'word2', \
        'cosine_sim_bert', \
        'cosine_sim_clip', \
        'cosine_sim_clip_face', \
        'cosine_sim_clip_face_angel', \
        'cosine_sim_glove', \
        'sim_bert', \
        'sim_clip_face', \
        'sim_clip_face_angel', \
        'sim_glove', \
        'total_occurrence', \
        'correct_row_idx', \
       ]

# all_pair_df[cols].head(200).sort_values(by=['cosine_sim_glove'], ascending=False)
# Out:
# Index(['word1', 'word2', 'total_occurrence', 'correct#', 'correct%',
#        'correct_row_idx', 'incorrect_row_idx', 'cosine_sim_bert',
#        'cosine_sim_clip_face', 'cosine_sim_clip_face_angel', 'sim_clip_face',
#        'sim_clip_face_angel', 'sim_glove', 'cosine_sim_glove', 'sim_bert',
#        'cosine_sim_clip'],
#       dtype='object')

# %%
all_pair_df[all_pair_df['cosine_sim_clip_face_angel'] <= all_pair_df['cosine_sim_glove']][cols]
# Out:
#                  word1         word2  cosine_sim_bert  cosine_sim_clip  \
# 0                small         large         0.991273         0.919434
# 10               short          long         0.916821         0.835938
# 130               oval   rectangular         0.986025         0.790527
# 280              thick          thin         0.993032         0.870605
# 285           vertical    horizontal         0.974451         0.881348
# 381               high           low         0.974972         0.877930
# 675              round         round         1.000000         0.995605
# 781           circular      circular         1.000000         0.994141
# 889              curve         curve         1.000000         0.991699
# 1052               two         three         0.992689         0.927246
# 1315         rectangle          oval         0.982541         0.817383
# 1343        vertically  horizontally         0.989841         0.895020
# 1345            upward      downward         0.967055         0.893555
# 1427              oval          oval         1.000000         0.994141
# 1483           segment          edge         0.991386         0.807129
# 1576               jag           jag         1.000000         0.992676
# 1836          upwardly    downwardly         0.998088         0.923828
# 2197                 u             u         1.000000         0.990723
# 2570          triangle      triangle         1.000000         0.992188
# 2635            beaker        beaker         1.000000         0.997559
# 3033              bean          bean         1.000000         0.992188
# 3769        horizontal    vertically         0.964531         0.880859
# 4099             below         above         0.995239         0.920898
# 4394            circle        circle         1.000000         0.991699
# 5350                 m             m         1.000000         0.991699
# 6159            bottom        corner         0.984311         0.812500
# 7152        diagonally    vertically         0.660778         0.868164
# 7654          scribble      scribble         1.000000         0.989258
# 8913         backwards      sideways         0.986846         0.850098
# 9161              less          than         0.938199         0.906738
# 9501         rightward      leftward         0.991216         0.916992
# 9591  counterclockwise     clockwise         0.946387         0.924316
# 9748                up          down         0.990728         0.875000
#
#       cosine_sim_clip_face  cosine_sim_clip_face_angel  cosine_sim_glove  \
# 0                 0.878418                    0.798340          0.861530
# 10                0.787598                    0.697754          0.820970
# 130               0.749023                    0.686035          0.690008
# 280               0.780273                    0.645996          0.756829
# 285               0.784180                    0.713867          0.926618
# 381               0.831055                    0.755859          0.781333
# 675               0.993652                    0.994629          1.000000
# 781               0.994629                    0.994629          1.000000
# 889               0.994141                    0.995117          1.000000
# 1052              0.912598                    0.899902          0.961781
# 1315              0.714844                    0.635742          0.647613
# 1343              0.710938                    0.661621          0.930509
# 1345              0.818359                    0.711426          0.885045
# 1427              0.997559                    0.988770          1.000000
# 1483              0.734863                    0.442627          0.448190
# 1576              0.998535                    0.997070          1.000000
# 1836              0.815918                    0.691406          0.898425
# 2197              0.990723                    0.997070          1.000000
# 2570              0.993652                    0.992676          1.000000
# 2635              0.998047                    0.998535          1.000000
# 3033              0.995117                    0.995605          1.000000
# 3769              0.709473                    0.605469          0.629645
# 4099              0.901855                    0.866699          0.894852
# 4394              0.994141                    0.997559          1.000000
# 5350              0.990234                    0.993652          1.000000
# 6159              0.742676                    0.528809          0.578271
# 7152              0.663574                    0.651367          0.674716
# 7654              0.993164                    0.995117          1.000000
# 8913              0.731934                    0.673340          0.697142
# 9161              0.893555                    0.781250          0.870692
# 9501              0.773926                    0.693359          0.898777
# 9591              0.839844                    0.793457          0.863718
# 9748              0.819336                    0.773438          0.868293
#
#         sim_bert  sim_clip_face  sim_clip_face_angel  sim_glove  \
# 0     247.298706       91.62500            72.375000  46.466022
# 10    218.175629       74.43750            58.750000  41.230141
# 130   252.116577       66.56250            51.281250  33.620979
# 280   222.410522       66.43750            43.281250  39.871071
# 285   230.793655       65.37500            49.125000  45.917988
# 381   206.060699       99.75000            75.562500  45.875874
# 675   225.575897      100.75000            94.750000  48.965923
# 781   256.345093      106.62500            99.312500  43.917061
# 889   263.405731      103.68750            88.437500  48.268700
# 1052  254.128830      108.50000            96.312500  48.476974
# 1315  229.899216       59.12500            43.062500  31.593485
# 1343  227.518219       58.71875            45.968750  45.649818
# 1345  214.027710       75.18750            53.843750  40.552528
# 1427  247.002426       86.37500            76.062500  50.662209
# 1483  211.330215       65.43750            26.265625  19.714151
# 1576  214.281097       64.00000            73.750000  50.744144
# 1836  294.755402       77.75000            43.281250  53.663612
# 2197  277.886597      129.12500            82.000000  56.367973
# 2570  261.239227       96.06250            99.625000  40.966866
# 2635  215.932846       60.00000            53.062500  39.776054
# 3033  218.809784       85.31250            73.312500  47.280415
# 3769  224.134918       53.62500            38.531250  31.229578
# 4099  219.226288       89.87500            82.000000  43.015244
# 4394  227.499252      116.12500           108.437500  41.604359
# 5350  236.297394      128.25000            64.875000  55.836388
# 6159  253.738586       63.84375            32.718750  26.579330
# 7152  168.287720       55.15625            44.750000  34.404610
# 7654  348.174042       92.68750            88.812500  38.448414
# 8913  222.157837       59.43750            43.000000  27.037661
# 9161  222.851776      121.06250            82.125000  42.541435
# 9501  347.689392       63.06250            41.562500  38.126163
# 9591  268.531311       73.31250            53.406250  45.395542
# 9748  228.396927       90.31250            73.562500  43.235432
#
#       total_occurrence                                    correct_row_idx
# 0                  228  [   1    7  101  145  204  220  260  275  382 ...
# 10                  68  [ 102  128  138  148  218  238  243  268  288 ...
# 130                 19  [1067 1944 2014 2018 2205 2208 2226 2278 2488 ...
# 280                 11  [ 328  398  423  463 1877 2694 3106 3134 4411 ...
# 285                 11  [ 236  984 1494 1602 1611 1613 1706 1790 1879 ...
# 381                  8          [1517 2580 3307 3693 3709 4799 5495 5498]
# 675                  5                         [ 920 3071 3715 4770 4774]
# 781                  4                              [3017 4067 4949 5170]
# 889                  4                              [ 922 3979 5036 5139]
# 1052                 3                                   [3055 3753 4696]
# 1315                 3                                   [ 599 2633 3088]
# 1343                 3                                   [ 379 1703 2642]
# 1345                 3                                   [ 378 3875 4534]
# 1427                 2                                        [5137 5444]
# 1483                 2                                        [4563 4833]
# 1576                 2                                        [3977 5083]
# 1836                 2                                        [2838 3224]
# 2197                 2                                        [1401 4417]
# 2570                 2                                          [176 917]
# 2635                 1                                             [5566]
# 3033                 1                                             [5329]
# 3769                 1                                             [4832]
# 4099                 1                                             [4606]
# 4394                 1                                             [4369]
# 5350                 1                                             [3782]
# 6159                 1                                             [3171]
# 7152                 1                                             [2400]
# 7654                 1                                             [1948]
# 8913                 1                                              [857]
# 9161                 1                                              [589]
# 9501                 1                                              [296]
# 9591                 1                                              [222]
# 9748                 1                                               [93]

# %%
for c in cols:
    if 'sim' in c:
        if 'glove' in c:
            print(c, all_pair_df[c][all_pair_df[c] >= -1].mean())
        else:
            print(c, all_pair_df[c].mean())
# Out:
# cosine_sim_bert 0.924697277390713
# cosine_sim_clip 0.8327558925799144
# cosine_sim_clip_face 0.7521660241747684
# cosine_sim_clip_face_angel 0.6914020807452058
# cosine_sim_glove 0.25908817080234237
# sim_bert 220.74610747250256
# sim_clip_face 74.52051705817978
# sim_clip_face_angel 59.0103953253843
# sim_glove 12.885511423475629

# %%
all_pair_df.to_csv('/raid/xiaoyuz1/amazon_turk/df_all_pair_word_pairs.csv', index=False)

# %%
np.sum(
    (all_pair_df['cosine_sim_bert'] > all_pair_df['cosine_sim_clip_face']) & 
    (all_pair_df['cosine_sim_clip_face'] > all_pair_df['cosine_sim_clip_face_angel'])
)

# %% [markdown]
# #### percentage change

# %%
c2 = 'cosine_sim_clip_face_angel'
c1 = 'cosine_sim_bert'
df = all_pair_df
df_new = df

# df_new = df[['word1','word2','total_occurrence',c1,c2]].copy()
df_new['change%'] = (df_new[c2] - df_new[c1]) / df_new[c1]
df_new['absChange%'] = abs((df_new[c2] - df_new[c1]) / df_new[c1])

# %%
df_new[(df_new['word1'] == 'small') & (df_new['word2'] == 'round')]
# Out:
#    word1  word2  total_occurrence  correct#  correct%  \
# 3  small  round               112       112       1.0
#
#                                      correct_row_idx incorrect_row_idx  \
# 3  [  46  101  145  220  260  395  400  470  635 ...                []
#
#    cosine_sim_bert  cosine_sim_clip_face  cosine_sim_clip_face_angel  change%  \
# 3         0.971433              0.856445                    0.739746  -0.2385
#
#    absChange%
# 3      0.2385

# %%
df_pos = df_new[df_new['change%'] > 0]
print(len(df_pos))
# Out:
# 259

# %%
print(df_pos['absChange%'].median())
# Out:
# 0.08953857737689182

# %%
df_new.iloc[df_pos['absChange%'].sort_values().index.tolist()].tail(100)
# Out:
#              word1          word2  total_occurrence  correct#  correct%  \
# 2072        curved    trapezoidal                 2         2       1.0
# 1982        curved     disconnect                 2         2       1.0
# 1087   trapezoidal          broad                 3         3       1.0
# 5889          spot          point                 1         1       1.0
# 1506         point          sided                 2         2       1.0
# 9626        gentle          point                 1         1       1.0
# 4859   marshmallow       slightly                 1         1       1.0
# 2079     scribbled       straight                 2         2       1.0
# 4519        antler          stick                 1         1       1.0
# 1891      squiggly         finger                 2         2       1.0
# 2704         point          thick                 1         1       1.0
# 5682      squiggly           eyed                 1         1       1.0
# 6573       largely                                1         1       1.0
# 5631      downward          point                 1         1       1.0
# 3692     trapezium           fork                 1         1       1.0
# 6785   trapezoidal           tilt                 1         1       1.0
# 8361         empty           tiny                 1         1       1.0
# 6422          tilt       unclosed                 1         1       1.0
# 3299         angle  quadrilateral                 1         1       1.0
# 6551           fat    trapezoidal                 1         1       1.0
# 6291         point         widely                 1         1       1.0
# 7034          half           jail                 1         1       1.0
# 1668        finger          curvy                 2         2       1.0
# 1667   trapezoidal         finger                 2         2       1.0
# 3217         stick           hump                 1         1       1.0
# 833       squiggly         curved                 4         4       1.0
# 6308         point          askew                 1         1       1.0
# 3059        deform          thick                 1         1       1.0
# 9500     rightward       pointing                 1         1       1.0
# 3085       frisbee           hook                 1         1       1.0
# 9517         curvy           hook                 1         1       1.0
# 4317          even    trapezoidal                 1         1       1.0
# 3214         curvy            not                 1         1       1.0
# 6774         thick       squiggly                 1         1       1.0
# 4331         point          leave                 1         1       1.0
# 7917       steeply         curved                 1         1       1.0
# 1950      slightly       unclosed                 2         2       1.0
# 1230      scribble         uneven                 3         3       1.0
# 5901        uneven      scribbled                 1         1       1.0
# 753    trapezoidal           tall                 4         4       1.0
# 7950        sleepy          awake                 1         1       1.0
# 3940           fin           hump                 1         1       1.0
# 7320        uneven       cucumber                 1         1       1.0
# 7385          bowl     watermelon                 1         1       1.0
# 5912            le                                1         1       1.0
# 2360         curvy           half                 2         2       1.0
# 4841       angular      scribbled                 1         1       1.0
# 5008     scribbled           tiny                 1         1       1.0
# 7225         right      scribbled                 1         1       1.0
# 3042   trapezoidal           arch                 1         1       1.0
# 3605         arrow         chubby                 1         1       1.0
# 2972        spread      scribbled                 1         1       1.0
# 8795      question            key                 1         1       1.0
# 7914  triangularly        crooked                 1         1       1.0
# 9624          bump          point                 1         1       1.0
# 6058                        great                 1         1       1.0
# 5841         angle       unclosed                 1         1       1.0
# 5737           fat          curvy                 1         1       1.0
# 4072         point           case                 1         1       1.0
# 9402        curved         putter                 1         1       1.0
# 3118      football         rotate                 1         1       1.0
# 4805          tall          point                 1         1       1.0
# 9581    semicircle           arch                 1         1       1.0
# 6782         point         finger                 1         1       1.0
# 2052        curved          point                 2         2       1.0
# 7376     christmas            bag                 1         1       1.0
# 8388        opened           over                 1         1       1.0
# 6426     perfectly          point                 1         1       1.0
# 5159       incisor          angle                 1         1       1.0
# 8425      slightly          point                 1         1       1.0
# 6523   trapezoidal           fill                 1         1       1.0
# 5168      cucumber         jagged                 1         1       1.0
# 7374      ornament            bag                 1         1       1.0
# 2830         point           worm                 1         1       1.0
# 6572       largely       hairless                 1         1       1.0
# 9637        jagged       scribble                 1         1       1.0
# 9375          boot          point                 1         1       1.0
# 1533         curvy           fill                 2         2       1.0
# 2971      downward      scribbled                 1         1       1.0
# 6911       frisbee           with                 1         1       1.0
# 5358       stretch    trapezoidal                 1         1       1.0
# 3200          hump         curved                 1         1       1.0
# 1352         curvy         curved                 3         3       1.0
# 9720         point      extremely                 1         1       1.0
# 884          point          angle                 4         4       1.0
# 1898   trapezoidal          angle                 2         2       1.0
# 8671       avocado         uneven                 1         1       1.0
# 3317         point          style                 1         1       1.0
# 4103         angle          curvy                 1         1       1.0
# 5628      pointing          point                 1         1       1.0
# 4117      squiggly          angle                 1         1       1.0
# 683           fill          empty                 5         5       1.0
# 3554    disconnect        connect                 1         1       1.0
# 4721          hump           fill                 1         1       1.0
# 8872        curved         border                 1         1       1.0
# 8427       crooked          point                 1         1       1.0
# 6462      pointing       scribble                 1         1       1.0
# 9331      leftward       downward                 1         1       1.0
# 1978      pointing      scribbled                 2         2       1.0
# 2522      pointing       leftward                 2         2       1.0
#
#                  correct_row_idx incorrect_row_idx  cosine_sim_bert  \
# 2072                 [1867 4602]                []         0.613408
# 1982                 [2314 2984]                []         0.693727
# 1087            [2742 2900 3503]                []         0.640108
# 5889                      [3347]                []         0.730059
# 1506                 [4426 5162]                []         0.642861
# 9626                       [188]                []         0.635628
# 4859                      [4082]                []         0.618844
# 2079                 [1822 2084]                []         0.644359
# 4519                      [4296]                []         0.585901
# 1891                 [2660 3478]                []         0.534279
# 2704                      [5513]                []         0.585715
# 5682                      [3514]                []         0.484989
# 6573                      [2865]                []         0.710588
# 5631                      [3550]                []         0.698798
# 3692                      [4878]                []         0.582712
# 6785                      [2691]                []         0.571830
# 8361                      [1336]                []         0.698612
# 6422                      [2977]                []         0.615821
# 3299                      [5165]                []         0.558325
# 6551                      [2872]                []         0.575145
# 6291                      [3068]                []         0.664787
# 7034                      [2467]                []         0.698994
# 1668                 [3478 5441]                []         0.584634
# 1667                 [3480 4602]                []         0.581917
# 3217                      [5213]                []         0.611297
# 833        [1960 1961 2694 4650]                []         0.554536
# 6308                      [3054]                []         0.653124
# 3059                      [5289]                []         0.524528
# 9500                       [296]                []         0.440010
# 3085                      [5274]                []         0.488930
# 9517                       [281]                []         0.579644
# 4317                      [4435]                []         0.585506
# 3214                      [5214]                []         0.622011
# 6774                      [2694]                []         0.466386
# 4331                      [4426]                []         0.712177
# 7917                      [1671]                []         0.597116
# 1950                 [2468 3049]                []         0.653676
# 1230            [1108 1643 2697]                []         0.560259
# 5901                      [3336]                []         0.562652
# 753        [4024 4538 4616 4988]                []         0.585329
# 7950                      [1648]                []         0.729930
# 3940                      [4703]                []         0.642148
# 7320                      [2256]                []         0.511696
# 7385                      [2210]                []         0.592013
# 5912                      [3334]                []         0.780780
# 2360                 [ 826 1974]                []         0.586463
# 4841                      [4093]                []         0.625870
# 5008                      [4002]                []         0.616415
# 7225                      [2337]                []         0.690360
# 3042                      [5303]                []         0.573273
# 3605                      [4957]                []         0.638066
# 2972                      [5372]                []         0.620095
# 8795                       [961]                []         0.652444
# 7914                      [1673]                []         0.543114
# 9624                       [188]                []         0.663273
# 6058                      [3234]                []         0.738810
# 5841                      [3384]                []         0.586402
# 5737                      [3478]                []         0.576946
# 4072                      [4630]                []         0.668464
# 9402                       [381]                []         0.587688
# 3118                      [5254]                []         0.607890
# 4805                      [4110]                []         0.639919
# 9581                       [227]                []         0.538472
# 6782                      [2693]                []         0.647861
# 2052                 [1961 4622]                []         0.666987
# 7376                      [2212]                []         0.582930
# 8388                      [1315]                []         0.662566
# 6426                      [2975]                []         0.688000
# 5159                      [3904]                []         0.446730
# 8425                      [1263]                []         0.673644
# 6523                      [2892]                []         0.564253
# 5168                      [3900]                []         0.449680
# 7374                      [2212]                []         0.545930
# 2830                      [5460]                []         0.616593
# 6572                      [2865]                []         0.509214
# 9637                       [183]                []         0.501095
# 9375                       [411]                []         0.573198
# 1533                 [4181 4740]                []         0.565814
# 2971                      [5372]                []         0.581837
# 6911                      [2610]                []         0.497131
# 5358                      [3777]                []         0.487315
# 3200                      [5222]                []         0.607870
# 1352            [ 332 5214 5222]                []         0.613964
# 9720                       [116]                []         0.629560
# 884        [1045 1081 2145 2842]                []         0.611225
# 1898                 [2646 3352]                []         0.542227
# 8671                      [1056]                []         0.513834
# 3317                      [5161]                []         0.616348
# 4103                      [4605]                []         0.543041
# 5628                      [3550]                []         0.594931
# 4117                      [4602]                []         0.487527
# 683   [ 796 1112 1336 1761 2448]                []         0.592968
# 3554                      [5011]                []         0.658590
# 4721                      [4181]                []         0.568662
# 8872                       [894]                []         0.556440
# 8427                      [1260]                []         0.554357
# 6462                      [2947]                []         0.477893
# 9331                       [451]                []         0.492251
# 1978                 [2337 5372]                []         0.466000
# 2522                   [296 451]                []         0.380811
#
#       cosine_sim_clip_face  cosine_sim_clip_face_angel   change%  absChange%
# 2072              0.746094                    0.688965  0.123176    0.123176
# 1982              0.828125                    0.780762  0.125459    0.125459
# 1087              0.789062                    0.721191  0.126671    0.126671
# 5889              0.903809                    0.826172  0.131651    0.131651
# 1506              0.857422                    0.728027  0.132481    0.132481
# 9626              0.866699                    0.720703  0.133844    0.133844
# 4859              0.804199                    0.702637  0.135401    0.135401
# 2079              0.860840                    0.731934  0.135910    0.135910
# 4519              0.766113                    0.666504  0.137571    0.137571
# 1891              0.778320                    0.608398  0.138727    0.138727
# 2704              0.802734                    0.668457  0.141267    0.141267
# 5682              0.787109                    0.555176  0.144719    0.144719
# 6573              0.908203                    0.813477  0.144793    0.144793
# 5631              0.887695                    0.800293  0.145241    0.145241
# 3692              0.758301                    0.667480  0.145473    0.145473
# 6785              0.775391                    0.656250  0.147631    0.147631
# 8361              0.864258                    0.801758  0.147644    0.147644
# 6422              0.834473                    0.707520  0.148904    0.148904
# 3299              0.725098                    0.641602  0.149154    0.149154
# 6551              0.759766                    0.661133  0.149507    0.149507
# 6291              0.908691                    0.764648  0.150216    0.150216
# 7034              0.883301                    0.805176  0.151907    0.151907
# 1668              0.780273                    0.674316  0.153399    0.153399
# 1667              0.743164                    0.671387  0.153749    0.153749
# 3217              0.810059                    0.706543  0.155809    0.155809
# 833               0.797852                    0.641113  0.156126    0.156126
# 6308              0.905762                    0.757812  0.160290    0.160290
# 3059              0.782715                    0.609375  0.161759    0.161759
# 9500              0.780762                    0.511230  0.161862    0.161862
# 3085              0.674805                    0.568359  0.162456    0.162456
# 9517              0.790527                    0.673828  0.162485    0.162485
# 4317              0.784668                    0.680664  0.162522    0.162522
# 3214              0.813965                    0.724609  0.164946    0.164946
# 6774              0.768555                    0.543457  0.165251    0.165251
# 4331              0.898926                    0.831055  0.166921    0.166921
# 7917              0.860352                    0.698242  0.169358    0.169358
# 1950              0.884277                    0.765625  0.171261    0.171261
# 1230              0.804199                    0.656250  0.171334    0.171334
# 5901              0.809082                    0.659180  0.171559    0.171559
# 753               0.756836                    0.686035  0.172051    0.172051
# 7950              0.907715                    0.857422  0.174664    0.174664
# 3940              0.806152                    0.754883  0.175559    0.175559
# 7320              0.750977                    0.602539  0.177534    0.177534
# 7385              0.743164                    0.698242  0.179438    0.179438
# 5912              0.959961                    0.920898  0.179459    0.179459
# 2360              0.815430                    0.691895  0.179776    0.179776
# 4841              0.793457                    0.738770  0.180389    0.180389
# 5008              0.821777                    0.729980  0.184235    0.184235
# 7225              0.863281                    0.818359  0.185409    0.185409
# 3042              0.762207                    0.681641  0.189033    0.189033
# 3605              0.813477                    0.760254  0.191498    0.191498
# 2972              0.828613                    0.739746  0.192956    0.192956
# 8795              0.873535                    0.778809  0.193679    0.193679
# 7914              0.731445                    0.650391  0.197522    0.197522
# 9624              0.914062                    0.803223  0.210999    0.210999
# 6058              0.922852                    0.896484  0.213417    0.213417
# 5841              0.812988                    0.714844  0.219033    0.219033
# 5737              0.847168                    0.707031  0.225472    0.225472
# 4072              0.910645                    0.820801  0.227891    0.227891
# 9402              0.808105                    0.723145  0.230490    0.230490
# 3118              0.833496                    0.748535  0.231367    0.231367
# 4805              0.840820                    0.788574  0.232304    0.232304
# 9581              0.831055                    0.669922  0.244117    0.244117
# 6782              0.875488                    0.806641  0.245082    0.245082
# 2052              0.875000                    0.830566  0.245250    0.245250
# 7376              0.811035                    0.729004  0.250586    0.250586
# 8388              0.883789                    0.829102  0.251350    0.251350
# 6426              0.914062                    0.862793  0.254060    0.254060
# 5159              0.780762                    0.562500  0.259150    0.259150
# 8425              0.924316                    0.848633  0.259764    0.259764
# 6523              0.771484                    0.717285  0.271213    0.271213
# 5168              0.717285                    0.572266  0.272605    0.272605
# 7374              0.795898                    0.699219  0.280785    0.280785
# 2830              0.862793                    0.791992  0.284464    0.284464
# 6572              0.848145                    0.655762  0.287793    0.287793
# 9637              0.754395                    0.646973  0.291118    0.291118
# 9375              0.847168                    0.742188  0.294818    0.294818
# 1533              0.823730                    0.734375  0.297909    0.297909
# 2971              0.839844                    0.756836  0.300770    0.300770
# 6911              0.733887                    0.650879  0.309272    0.309272
# 5358              0.732910                    0.638184  0.309590    0.309590
# 3200              0.836914                    0.796875  0.310931    0.310931
# 1352              0.882812                    0.805176  0.311438    0.311438
# 9720              0.905273                    0.827637  0.314626    0.314626
# 884               0.859375                    0.809082  0.323705    0.323705
# 1898              0.785156                    0.721191  0.330054    0.330054
# 8671              0.741699                    0.687500  0.337981    0.337981
# 3317              0.909668                    0.843750  0.368951    0.368951
# 4103              0.829102                    0.748535  0.378413    0.378413
# 5628              0.873047                    0.823242  0.383760    0.383760
# 4117              0.812012                    0.676270  0.387143    0.387143
# 683               0.893066                    0.829102  0.398222    0.398222
# 3554              0.940918                    0.920898  0.398289    0.398289
# 4721              0.861328                    0.802734  0.411619    0.411619
# 8872              0.849609                    0.793945  0.426831    0.426831
# 8427              0.886719                    0.806641  0.455092    0.455092
# 6462              0.781250                    0.696289  0.456999    0.456999
# 9331              0.843262                    0.733887  0.490879    0.490879
# 1978              0.798828                    0.730957  0.568578    0.568578
# 2522              0.785645                    0.669922  0.759196    0.759196

# %%
all_pair_s = rd.all_pair_together(dfp)
all_pair_s
# Out:
#              word1      word2  total_occurrence  correct#  correct%  \
# 0            small      round               228       228       1.0
# 1            small   circular               176       176       1.0
# 2         vertical       line               168       168       1.0
# 3         circular       open               150       150       1.0
# 4            small       oval               150       150       1.0
# ...            ...        ...               ...       ...       ...
# 5744         bumpy   circular                 2         2       1.0
# 5745         perky   vertical                 2         2       1.0
# 5746          wavy      small                 2         2       1.0
# 5747  asymmetrical  surprised                 2         2       1.0
# 5748        shorty     spikey                 2         2       1.0
#
#                                         correct_row_idx incorrect_row_idx
# 0     [100, 100, 180, 180, 210, 210, 220, 220, 260, ...                []
# 1     [206, 206, 240, 240, 792, 792, 796, 796, 864, ...                []
# 2     [26, 26, 110, 110, 170, 170, 175, 175, 235, 23...                []
# 3     [135, 135, 185, 185, 274, 274, 621, 621, 756, ...                []
# 4     [110, 110, 656, 656, 676, 676, 729, 729, 1160,...                []
# ...                                                 ...               ...
# 5744                                           [24, 24]                []
# 5745                                             [6, 6]                []
# 5746                                             [6, 6]                []
# 5747                                             [5, 5]                []
# 5748                                             [3, 3]                []
#
# [5749 rows x 7 columns]

# %%
all_pair_s[(all_pair_s['word1'] == 'leftward') & (all_pair_s['word2'] == 'pointing')]
# Out:
#          word1     word2  total_occurrence  correct#  correct%  \
# 1691  leftward  pointing                 4         4       1.0
#
#            correct_row_idx incorrect_row_idx
# 1691  [296, 296, 451, 451]                []

# %%
all_pair_df = rd.all_pair_combination(dfp, wrong_rows=[])

# %%
len(all_pair_df)
# Out:
# 9823

# %% [markdown]
# ### wrong rows

# %%
dfo[dfo['image_1'] == 687]
# Out:
#        image_1       worker_id  part category   time  \
# 912        687   A4D99Y82KOLC8     1     face   34.6
# 1772       687   APRZ7BR8C0ZMQ     2     face   92.0
# 3104       687   AWVLT2L5AP873     0     face   94.8
# 3333       687  A3AJJHOAV7WIUQ     0     face  231.2
# 4116       687   A1198W1SPF1R4     2     face  307.4
# 4426       687  A1YSYI926BBOHW     6     face  151.8
# 4756       687  A2K6VG008QFOPN     1     face  496.2
# 4766       687  A3AJJHOAV7WIUQ     6     face  170.6
# 5509       687  A33LYSCQQU1YDJ     5    angel   43.8
# 6029       687  A12R2U6TBB3OOG     4    angel   88.4
# 6157       687  A37GOI3N77WX21     7    angel  369.6
# 6195       687  A280KACF4T7RJQ     3    angel  636.8
# 7371       687  A2JP9IKRHNLRPI     0    angel  372.2
# 7975       687  A2JP9IKRHNLRPI     1    angel  571.2
# 8281       687  A3TBG0S2IEBVHU     5    angel  643.2
# 8781       687  A3AJJHOAV7WIUQ     4    angel  180.4
# 9298       687  A1SX8IVV82M0LW     7    angel  596.6
# 9398       687  A173MXK429XAZQ     3    angel  613.8
# 9693       687   APRZ7BR8C0ZMQ     1    angel  439.2
# 10321      687  A2QX3YJXAAHHVV     0    angel  143.2
#
#                                                 folder  \
# 912      /raid/xiaoyuz1/amazon_turk/2022_03_22_release
# 1772     /raid/xiaoyuz1/amazon_turk/2022_03_23_release
# 3104   /raid/xiaoyuz1/amazon_turk/2022_03_24_release_2
# 3333   /raid/xiaoyuz1/amazon_turk/2022_03_24_release_2
# 4116     /raid/xiaoyuz1/amazon_turk/2022_04_04_release
# 4426   /raid/xiaoyuz1/amazon_turk/2022_04_04_release_2
# 4756   /raid/xiaoyuz1/amazon_turk/2022_04_04_release_2
# 4766   /raid/xiaoyuz1/amazon_turk/2022_04_04_release_2
# 5509     /raid/xiaoyuz1/amazon_turk/2022_04_05_release
# 6029     /raid/xiaoyuz1/amazon_turk/2022_04_06_release
# 6157     /raid/xiaoyuz1/amazon_turk/2022_04_06_release
# 6195     /raid/xiaoyuz1/amazon_turk/2022_04_06_release
# 7371     /raid/xiaoyuz1/amazon_turk/2022_04_06_release
# 7975   /raid/xiaoyuz1/amazon_turk/2022_04_06_release_2
# 8281   /raid/xiaoyuz1/amazon_turk/2022_04_06_release_2
# 8781   /raid/xiaoyuz1/amazon_turk/2022_04_06_release_2
# 9298   /raid/xiaoyuz1/amazon_turk/2022_04_06_release_2
# 9398   /raid/xiaoyuz1/amazon_turk/2022_04_06_release_2
# 9693   /raid/xiaoyuz1/amazon_turk/2022_04_06_release_3
# 10321  /raid/xiaoyuz1/amazon_turk/2022_04_06_release_3
#
#                                 text_1  \
# 912                           s-shaped
# 1772                    subtly-smiling
# 3104                       dot-pupiled
# 3333                              dots
# 4116                         thin lips
# 4426                             olive
# 4756                        Big pointy
# 4766                         fast loop
# 5509                        triangular
# 6029                             messy
# 6157             upward crescent broad
# 6195                  horizontal curve
# 7371                           pumpkin
# 7975                  small rectangles
# 8281          angular, upward-pointing
# 8781                            walnut
# 9298                       thin pointy
# 9398   flat, unsmiling, straight, line
# 9693                    quotation-mark
# 10321               oblong, oval, open
#
#                                              tokenized_1  \
# 912                                           ['s', '-']
# 1772                            ['subtly', '-', 'smile']
# 3104                              ['dot', '-', 'pupile']
# 3333                                             ['dot']
# 4116                                     ['thin', 'lip']
# 4426                                           ['olive']
# 4756                                   ['big', 'pointy']
# 4766                                    ['fast', 'loop']
# 5509                                      ['triangular']
# 6029                                           ['messy']
# 6157                     ['upward', 'crescent', 'broad']
# 6195                             ['horizontal', 'curve']
# 7371                                         ['pumpkin']
# 7975                              ['small', 'rectangle']
# 8281         ['angular', ',', 'upward', '-', 'pointing']
# 8781                                          ['walnut']
# 9298                                  ['thin', 'pointy']
# 9398   ['flat', ',', 'unsmiling', ',', 'straight', ',...
# 9693                          ['quotation', '-', 'mark']
# 10321               ['oblong', ',', 'oval', ',', 'open']
#
#                                                  lower_1  \
# 912                                           ['s', '-']
# 1772                            ['subtly', '-', 'smile']
# 3104                              ['dot', '-', 'pupile']
# 3333                                             ['dot']
# 4116                                     ['thin', 'lip']
# 4426                                           ['olive']
# 4756                                   ['big', 'pointy']
# 4766                                    ['fast', 'loop']
# 5509                                      ['triangular']
# 6029                                           ['messy']
# 6157                     ['upward', 'crescent', 'broad']
# 6195                             ['horizontal', 'curve']
# 7371                                         ['pumpkin']
# 7975                              ['small', 'rectangle']
# 8281         ['angular', ',', 'upward', '-', 'pointing']
# 8781                                          ['walnut']
# 9298                                  ['thin', 'pointy']
# 9398   ['flat', ',', 'unsmiling', ',', 'straight', ',...
# 9693                          ['quotation', '-', 'mark']
# 10321               ['oblong', ',', 'oval', ',', 'open']
#
#                                no_punc_1                 no_punc_str_1
# 912                                  [s]                             s
# 1772                     [subtly, smile]                  subtly smile
# 3104                       [dot, pupile]                    dot pupile
# 3333                               [dot]                           dot
# 4116                         [thin, lip]                      thin lip
# 4426                             [olive]                         olive
# 4756                       [big, pointy]                    big pointy
# 4766                        [fast, loop]                     fast loop
# 5509                        [triangular]                    triangular
# 6029                             [messy]                         messy
# 6157           [upward, crescent, broad]         upward crescent broad
# 6195                 [horizontal, curve]              horizontal curve
# 7371                           [pumpkin]                       pumpkin
# 7975                  [small, rectangle]               small rectangle
# 8281         [angular, upward, pointing]       angular upward pointing
# 8781                            [walnut]                        walnut
# 9298                      [thin, pointy]                   thin pointy
# 9398   [flat, unsmiling, straight, line]  flat unsmiling straight line
# 9693                   [quotation, mark]                quotation mark
# 10321               [oblong, oval, open]              oblong oval open

# %%
dfii = rd.find_one(dfo, 'spiky', 'no_punc_1')
print(len(dfii))
dfii
# Out:
# 43
#        image_1       worker_id  part category   time  \
# 27         335  A1F6MWP9A0XLJQ     4     face  153.4
# 36         592  A2JDYN6QM8M5UN     4     face  117.4
# 97           3  A320QA9HJFUOZO     4     face   86.6
# 146        402  A1PTH9KTRO06EG     4     face   69.2
# 166         59  A272X64FOZFYLB     4     face  190.0
# 227         18   AKQAI78JTXXC9     4     face  366.0
# 297        465  A2AAY4VT9L71SY     4     face   75.6
# 406        192   AHYTT3T8W9Y9Y     4     face  210.4
# 446        688  A2NAKIXS3DVGAA     4     face   80.6
# 687        609  A1VMPZVVVZUCS4     4     face  143.6
# 726        516  A1PTH9KTRO06EG     4     face  714.2
# 736        100   APGX2WZ59OWDN     4     face  335.0
# 787          3  A2541C8MY0BYV3     4     face  468.2
# 867        255  A320QA9HJFUOZO     4     face  110.4
# 887        255   APGX2WZ59OWDN     4     face  305.0
# 946        552  A2NAKIXS3DVGAA     4     face  294.8
# 1752        48  A272X64FOZFYLB     0     face  302.2
# 3862       474   APGX2WZ59OWDN     4     face  170.6
# 3884       126   AHYTT3T8W9Y9Y     4     face  245.8
# 4630       460  A3UV55HC87DO9C     4     face  307.6
# 5184       275   AHYTT3T8W9Y9Y     7    angel  197.0
# 5609       787   AHYTT3T8W9Y9Y     7    angel  197.6
# 5637       658   AHYTT3T8W9Y9Y     7    angel  166.2
# 5803       382   AHYTT3T8W9Y9Y     7    angel   89.2
# 6605       738   APGX2WZ59OWDN     7    angel  531.4
# 6616       163   APGX2WZ59OWDN     7    angel  133.0
# 6862       393  A2NAKIXS3DVGAA     7    angel  172.2
# 7047       547   AHYTT3T8W9Y9Y     7    angel  344.6
# 7867       265   APGX2WZ59OWDN     7    angel  423.8
# 8150        42   AWVLT2L5AP873     7    angel   90.6
# 8440       573   AWVLT2L5AP873     7    angel  118.2
# 8682       364  A1DMXEJGJY02E1     7    angel   80.6
# 9214       336  A1DMXEJGJY02E1     7    angel  680.4
# 9481       479  A272X64FOZFYLB     7    angel  577.0
# 9586       227   APGX2WZ59OWDN     7    angel  676.2
# 9651       341  A272X64FOZFYLB     7    angel  120.4
# 9659       215  A272X64FOZFYLB     7    angel  120.4
# 9776       275  A272X64FOZFYLB     7    angel   55.2
# 10383      469  A3C8JI69WPTKWH     7    angel  534.2
# 10447      428  A272X64FOZFYLB     7    angel  329.4
# 10500      616  A2NAKIXS3DVGAA     7    angel  319.6
# 10501      486  A2NAKIXS3DVGAA     7    angel  319.6
# 10962      427   APGX2WZ59OWDN     7    angel  673.6
#
#                                                 folder  \
# 27       /raid/xiaoyuz1/amazon_turk/2022_03_21_release
# 36       /raid/xiaoyuz1/amazon_turk/2022_03_21_release
# 97       /raid/xiaoyuz1/amazon_turk/2022_03_21_release
# 146      /raid/xiaoyuz1/amazon_turk/2022_03_21_release
# 166      /raid/xiaoyuz1/amazon_turk/2022_03_21_release
# 227      /raid/xiaoyuz1/amazon_turk/2022_03_21_release
# 297      /raid/xiaoyuz1/amazon_turk/2022_03_21_release
# 406      /raid/xiaoyuz1/amazon_turk/2022_03_21_release
# 446      /raid/xiaoyuz1/amazon_turk/2022_03_21_release
# 687      /raid/xiaoyuz1/amazon_turk/2022_03_22_release
# 726      /raid/xiaoyuz1/amazon_turk/2022_03_22_release
# 736      /raid/xiaoyuz1/amazon_turk/2022_03_22_release
# 787      /raid/xiaoyuz1/amazon_turk/2022_03_22_release
# 867      /raid/xiaoyuz1/amazon_turk/2022_03_22_release
# 887      /raid/xiaoyuz1/amazon_turk/2022_03_22_release
# 946      /raid/xiaoyuz1/amazon_turk/2022_03_22_release
# 1752     /raid/xiaoyuz1/amazon_turk/2022_03_23_release
# 3862     /raid/xiaoyuz1/amazon_turk/2022_04_04_release
# 3884     /raid/xiaoyuz1/amazon_turk/2022_04_04_release
# 4630   /raid/xiaoyuz1/amazon_turk/2022_04_04_release_2
# 5184     /raid/xiaoyuz1/amazon_turk/2022_04_05_release
# 5609     /raid/xiaoyuz1/amazon_turk/2022_04_06_release
# 5637     /raid/xiaoyuz1/amazon_turk/2022_04_06_release
# 5803     /raid/xiaoyuz1/amazon_turk/2022_04_06_release
# 6605     /raid/xiaoyuz1/amazon_turk/2022_04_06_release
# 6616     /raid/xiaoyuz1/amazon_turk/2022_04_06_release
# 6862     /raid/xiaoyuz1/amazon_turk/2022_04_06_release
# 7047     /raid/xiaoyuz1/amazon_turk/2022_04_06_release
# 7867   /raid/xiaoyuz1/amazon_turk/2022_04_06_release_2
# 8150   /raid/xiaoyuz1/amazon_turk/2022_04_06_release_2
# 8440   /raid/xiaoyuz1/amazon_turk/2022_04_06_release_2
# 8682   /raid/xiaoyuz1/amazon_turk/2022_04_06_release_2
# 9214   /raid/xiaoyuz1/amazon_turk/2022_04_06_release_2
# 9481   /raid/xiaoyuz1/amazon_turk/2022_04_06_release_2
# 9586   /raid/xiaoyuz1/amazon_turk/2022_04_06_release_3
# 9651   /raid/xiaoyuz1/amazon_turk/2022_04_06_release_3
# 9659   /raid/xiaoyuz1/amazon_turk/2022_04_06_release_3
# 9776   /raid/xiaoyuz1/amazon_turk/2022_04_06_release_3
# 10383  /raid/xiaoyuz1/amazon_turk/2022_04_06_release_3
# 10447  /raid/xiaoyuz1/amazon_turk/2022_04_06_release_3
# 10500  /raid/xiaoyuz1/amazon_turk/2022_04_06_release_3
# 10501  /raid/xiaoyuz1/amazon_turk/2022_04_06_release_3
# 10962  /raid/xiaoyuz1/amazon_turk/2022_04_06_release_3
#
#                                            text_1  \
# 27                                          spiky
# 36                                          spiky
# 97                                     spiky tall
# 146                                         spiky
# 166                              spiky zig-zagged
# 227                                    spiky hair
# 297                                   short spiky
# 406                                         spiky
# 446                                         spiky
# 687                                         spiky
# 726                                         spiky
# 736                                         spiky
# 787                                         spiky
# 867                                   short spiky
# 887                                         spiky
# 946                                    tall spiky
# 1752                               spiky circular
# 3862                                        spiky
# 3884                                        spiky
# 4630                                        spiky
# 5184                                 spiky, sharp
# 5609                                jagged, spiky
# 5637                       spiky, jagged, pointed
# 5803                                 spiky, sharp
# 6605                                        spiky
# 6616                                        spiky
# 6862   straight line-shaped and spiky club-shaped
# 7047                         jagged, spiky, sharp
# 7867                                        spiky
# 8150                           asymmetrical spiky
# 8440                                spiky, flared
# 8682                                        spiky
# 9214                                        spiky
# 9481                      spiky projection-filled
# 9586                                        spiky
# 9651                            spiky, zig-zagged
# 9659                      spiky projection-shaped
# 9776                            spiky, zig-zagged
# 10383                                       spiky
# 10447                           spiky, zig-zagged
# 10500                      spiky rotated U-shaped
# 10501                     spiky candy-cane-shaped
# 10962                                       spiky
#
#                                            tokenized_1  \
# 27                                           ['spiky']
# 36                                           ['spiky']
# 97                                   ['spiky', 'tall']
# 146                                          ['spiky']
# 166                    ['spiky', 'zig', '-', 'zagged']
# 227                                  ['spiky', 'hair']
# 297                                 ['short', 'spiky']
# 406                                          ['spiky']
# 446                                          ['spiky']
# 687                                          ['spiky']
# 726                                          ['spiky']
# 736                                          ['spiky']
# 787                                          ['spiky']
# 867                                 ['short', 'spiky']
# 887                                          ['spiky']
# 946                                  ['tall', 'spiky']
# 1752                             ['spiky', 'circular']
# 3862                                         ['spiky']
# 3884                                         ['spiky']
# 4630                                         ['spiky']
# 5184                           ['spiky', ',', 'sharp']
# 5609                             ['jag', ',', 'spiky']
# 5637            ['spiky', ',', 'jagged', ',', 'point']
# 5803                           ['spiky', ',', 'sharp']
# 6605                                         ['spiky']
# 6616                                         ['spiky']
# 6862   ['straight', 'line', '-', 'spiky', 'club', '-']
# 7047            ['jagged', ',', 'spiky', ',', 'sharp']
# 7867                                         ['spiky']
# 8150                         ['asymmetrical', 'spiky']
# 8440                           ['spiky', ',', 'flare']
# 8682                                         ['spiky']
# 9214                                         ['spiky']
# 9481              ['spiky', 'projection', '-', 'fill']
# 9586                                         ['spiky']
# 9651              ['spiky', ',', 'zig', '-', 'zagged']
# 9659                      ['spiky', 'projection', '-']
# 9776              ['spiky', ',', 'zig', '-', 'zagged']
# 10383                                        ['spiky']
# 10447             ['spiky', ',', 'zig', '-', 'zagged']
# 10500                    ['spiky', 'rotate', 'u', '-']
# 10501             ['spiky', 'candy', '-', 'cane', '-']
# 10962                                        ['spiky']
#
#                                                lower_1  \
# 27                                           ['spiky']
# 36                                           ['spiky']
# 97                                   ['spiky', 'tall']
# 146                                          ['spiky']
# 166                    ['spiky', 'zig', '-', 'zagged']
# 227                                  ['spiky', 'hair']
# 297                                 ['short', 'spiky']
# 406                                          ['spiky']
# 446                                          ['spiky']
# 687                                          ['spiky']
# 726                                          ['spiky']
# 736                                          ['spiky']
# 787                                          ['spiky']
# 867                                 ['short', 'spiky']
# 887                                          ['spiky']
# 946                                  ['tall', 'spiky']
# 1752                             ['spiky', 'circular']
# 3862                                         ['spiky']
# 3884                                         ['spiky']
# 4630                                         ['spiky']
# 5184                           ['spiky', ',', 'sharp']
# 5609                             ['jag', ',', 'spiky']
# 5637            ['spiky', ',', 'jagged', ',', 'point']
# 5803                           ['spiky', ',', 'sharp']
# 6605                                         ['spiky']
# 6616                                         ['spiky']
# 6862   ['straight', 'line', '-', 'spiky', 'club', '-']
# 7047            ['jagged', ',', 'spiky', ',', 'sharp']
# 7867                                         ['spiky']
# 8150                         ['asymmetrical', 'spiky']
# 8440                           ['spiky', ',', 'flare']
# 8682                                         ['spiky']
# 9214                                         ['spiky']
# 9481              ['spiky', 'projection', '-', 'fill']
# 9586                                         ['spiky']
# 9651              ['spiky', ',', 'zig', '-', 'zagged']
# 9659                      ['spiky', 'projection', '-']
# 9776              ['spiky', ',', 'zig', '-', 'zagged']
# 10383                                        ['spiky']
# 10447             ['spiky', ',', 'zig', '-', 'zagged']
# 10500                    ['spiky', 'rotate', 'u', '-']
# 10501             ['spiky', 'candy', '-', 'cane', '-']
# 10962                                        ['spiky']
#
#                            no_punc_1             no_punc_str_1
# 27                           [spiky]                     spiky
# 36                           [spiky]                     spiky
# 97                     [spiky, tall]                spiky tall
# 146                          [spiky]                     spiky
# 166             [spiky, zig, zagged]          spiky zig zagged
# 227                    [spiky, hair]                spiky hair
# 297                   [short, spiky]               short spiky
# 406                          [spiky]                     spiky
# 446                          [spiky]                     spiky
# 687                          [spiky]                     spiky
# 726                          [spiky]                     spiky
# 736                          [spiky]                     spiky
# 787                          [spiky]                     spiky
# 867                   [short, spiky]               short spiky
# 887                          [spiky]                     spiky
# 946                    [tall, spiky]                tall spiky
# 1752               [spiky, circular]            spiky circular
# 3862                         [spiky]                     spiky
# 3884                         [spiky]                     spiky
# 4630                         [spiky]                     spiky
# 5184                  [spiky, sharp]               spiky sharp
# 5609                    [jag, spiky]                 jag spiky
# 5637          [spiky, jagged, point]        spiky jagged point
# 5803                  [spiky, sharp]               spiky sharp
# 6605                         [spiky]                     spiky
# 6616                         [spiky]                     spiky
# 6862   [straight, line, spiky, club]  straight line spiky club
# 7047          [jagged, spiky, sharp]        jagged spiky sharp
# 7867                         [spiky]                     spiky
# 8150           [asymmetrical, spiky]        asymmetrical spiky
# 8440                  [spiky, flare]               spiky flare
# 8682                         [spiky]                     spiky
# 9214                         [spiky]                     spiky
# 9481       [spiky, projection, fill]     spiky projection fill
# 9586                         [spiky]                     spiky
# 9651            [spiky, zig, zagged]          spiky zig zagged
# 9659             [spiky, projection]          spiky projection
# 9776            [spiky, zig, zagged]          spiky zig zagged
# 10383                        [spiky]                     spiky
# 10447           [spiky, zig, zagged]          spiky zig zagged
# 10500             [spiky, rotate, u]            spiky rotate u
# 10501           [spiky, candy, cane]          spiky candy cane
# 10962                        [spiky]                     spiky

# %%
dfii.iloc[10]
# Out:
# image_1                                                    516
# worker_id                                       A1PTH9KTRO06EG
# part                                                         4
# category                                                  face
# time                                                     714.2
# folder           /raid/xiaoyuz1/amazon_turk/2022_03_22_release
# text_1                                                   spiky
# tokenized_1                                          ['spiky']
# lower_1                                              ['spiky']
# no_punc_1                                              [spiky]
# no_punc_str_1                                            spiky
# Name: 726, dtype: object

# %%
row_figsize = 3
column_figsize = 3
num_pngs_per_row = 5
num_rows = len(dfii) // num_pngs_per_row
if num_rows * num_pngs_per_row < len(png_indices):
    num_rows += 1

fig = plt.figure(figsize=(num_pngs_per_row * row_figsize, num_rows * column_figsize)) 
fig.patch.set_alpha(1)  

for index in range(len(dfii)):
    plt.subplot(num_rows, num_pngs_per_row, index+1)
    
    row = dfii.iloc[index]
    idx = row['image_1']
    color_selected_part = [int(row['part'])]
    
    if row['category'] == 'face':
        drawing_raw = CONST.face_json['train_data'][idx]
    else:
        drawing_raw = CONST.angel_json['train_data'][idx]
    image_data = rd.transform_spg_2_svg_png(
        drawing_raw, 
        draw_color = True, 
        stroke_width = 3,
        color_selected = color_selected_part,
    )
    plt.imshow(image_data)
    plt.axis('off')
plt.subplots_adjust(wspace=0, hspace=0)
plt.show()
plt.close()

# %%
png_indices = [402]
color_selected_part = [4]
obj = CONST.face_json
# obj = CONST.angel_json

row_figsize = 6
column_figsize = 6
num_pngs_per_row = 1
num_rows = 1

fig = plt.figure(figsize=(num_pngs_per_row * row_figsize, num_rows * column_figsize)) 
fig.patch.set_alpha(1)  

for index, idx in enumerate(png_indices):
    plt.subplot(num_rows, num_pngs_per_row, index+1)

    drawing_raw = obj['train_data'][idx]
    image_data = rd.transform_spg_2_svg_png(
        drawing_raw, 
        draw_color = True, 
        stroke_width = 3,
        color_selected = color_selected_part,
    )

    plt.imshow(image_data)
    plt.axis('off')

plt.show()
plt.close()

# %%
dfp = get_df()
template_1,template_2 = template[0]
dfp['caption_1'] = dfp.apply(template_1, axis=1)
dfp['caption_2'] = dfp.apply(template_2, axis=1)

# %%
root_folder = '/raid/xiaoyuz1/clip_model_checkpoint'
acc_path_name = os.path.join(root_folder, "pleasant-tree-10.pickle")
final_accs, preds, gts = None,None,None
with open(acc_path_name, 'rb') as f:
    _, final_accs, preds, gts = pickle.load(f)
print(final_accs)
# Out:
# {'test': {'face': 0.7430830039525692, 'angel': 0.7035830618892508}, 'dev': {'face': 0.7171314741035857, 'angel': 0.7100977198697068}, 'train': 0.9284064665127021}

# %%
cat = 'face'
split = 'test'
pred,gt = preds[split][cat], gts[split][cat]
                        
reload(rd)
df_cat = dfp[(dfp['category'] == cat) & (dfp['split'] == split)]
df_cat = df_cat.reset_index(drop=True)

# %%
np.sum(np.argmax(pred, axis=1).reshape(-1,) == gt) / len(gt)
# Out:
# 0.6620553359683794

# %%
def get_wrong(pred, gt):
    wrong = []
    for i in np.where(np.argmax(pred, axis=1).reshape(-1,) != gt)[0]:
        row = i // 2
        col = i % 2
        wrong.append((row,col))
    wrong_rows = list(np.unique([x[0] for x in wrong]))
    return wrong_rows

# %%
pred.shape, len(df_cat)
# Out:
# ((506, 2, 2), 506)

# %%
# dfo[dfo.apply(lambda x: 'l' in x['no_punc_1'], axis=1)]

# %%
wrong = get_wrong(pred,gt)

# %%
all_pair_df = rd.all_pair_combination(df_cat, wrong_rows=wrong)

# %%
all_pair_df
# Out:
#         word1       word2  total_occurrence  correct#  correct%  \
# 0       small       large                18        16  0.888889
# 1       short        long                16         8  0.500000
# 2       close        open                14         6  0.428571
# 3        wide       small                12        10  0.833333
# 4        wide       curve                10         3  0.300000
# ...       ...         ...               ...       ...       ...
# 1264  crooked    sideways                 1         1  1.000000
# 1265  crooked        open                 1         1  1.000000
# 1266       an  triangular                 1         0  0.000000
# 1267   within  triangular                 1         0  0.000000
# 1268    spiky        long                 1         1  1.000000
#
#                                         correct_row_idx  \
# 0     [75, 195, 228, 229, 236, 286, 303, 319, 322, 3...
# 1                 [27, 82, 89, 111, 216, 434, 472, 498]
# 2                         [88, 263, 281, 300, 308, 387]
# 3      [12, 64, 167, 176, 179, 216, 257, 335, 412, 495]
# 4                                        [82, 167, 265]
# ...                                                 ...
# 1264                                                [3]
# 1265                                                [3]
# 1266                                                 []
# 1267                                                 []
# 1268                                                [0]
#
#                             incorrect_row_idx
# 0                                  [416, 421]
# 1         [13, 21, 67, 68, 86, 113, 215, 285]
# 2     [20, 274, 282, 326, 328, 345, 390, 504]
# 3                                  [262, 460]
# 4         [253, 262, 280, 292, 346, 360, 389]
# ...                                       ...
# 1264                                       []
# 1265                                       []
# 1266                                      [2]
# 1267                                      [2]
# 1268                                       []
#
# [1269 rows x 7 columns]

# %%
dfnii = all_pair_df[(all_pair_df['word1'] == 'small') & (all_pair_df['word2'] == 'large')]
dfnii
# Out:
#    word1  word2  total_occurrence  correct#  correct%  \
# 0  small  large                18        16  0.888889
#
#                                      correct_row_idx incorrect_row_idx
# 0  [75, 195, 228, 229, 236, 286, 303, 319, 322, 3...        [416, 421]

# %%
for l in dfnii['correct_row_idx']:
    for row_idx in l:
        row = df_cat.iloc[row_idx]
        print(pred[row_idx])
        p1,p2 = row['image_1'], row['image_2']
        part_idx = row['part']

        w1 = row['no_punc_str_1']
        w2 = row['no_punc_str_2']
        # print(w1,", ", w2)
        ws = [w1,w2]
        plt.figure(figsize=(10,5))
        for i,p in enumerate([p1,p2]):
            img = PIL.Image.open('/raid/xiaoyuz1/sketch_datasets/{}_images_weight_5_all/{}.png'.format(cat,p))
            plt.subplot(1,2,i+1)
            img = img.convert(mode='RGB')
            plt.imshow(img)
            plt.title("{} {}".format(ws[i], CONST.face_parts_idx_dict[part_idx]))
        plt.show()
# Out:
# [[0.2413 0.232 ]
#  [0.212  0.2537]]
# [[0.2328 0.2477]
#  [0.2277 0.2484]]
# [[0.2267 0.2131]
#  [0.2083 0.2266]]
# [[0.2732 0.2363]
#  [0.2676 0.2474]]
# [[0.2422 0.2542]
#  [0.1974 0.261 ]]
# [[0.2212 0.2104]
#  [0.2168 0.2708]]
# [[0.2217 0.1617]
#  [0.1354 0.213 ]]
# [[0.2288 0.1995]
#  [0.148  0.2537]]
# [[0.2251 0.2178]
#  [0.1411 0.2292]]
# [[0.2366 0.1978]
#  [0.1904 0.2394]]
# [[0.2461 0.228 ]
#  [0.2263 0.2345]]
# [[0.2646 0.2031]
#  [0.217  0.232 ]]
# [[0.2507 0.1626]
#  [0.2115 0.1984]]
# [[0.248  0.1716]
#  [0.2035 0.2336]]
# [[0.2438 0.2212]
#  [0.2267 0.2306]]
# [[0.231  0.2241]
#  [0.2247 0.2338]]

# %%
for l in dfnii['correct_row_idx']:
    for row_idx in l:
        row = df_cat.iloc[row_idx]
        print(pred[row_idx])
        p1,p2 = row['image_1'], row['image_2']
        part_idx = row['part']

        w1 = row['no_punc_str_1']
        w2 = row['no_punc_str_2']
        # print(w1,", ", w2)
        ws = [w1,w2]
        plt.figure(figsize=(10,5))
        for i,p in enumerate([p1,p2]):
            img = PIL.Image.open('/raid/xiaoyuz1/sketch_datasets/{}_images_weight_5_all/{}.png'.format(cat,p))
            plt.subplot(1,2,i+1)
            img = img.convert(mode='RGB')
            plt.imshow(img)
            plt.title("{} {}".format(ws[i], CONST.face_parts_idx_dict[part_idx]))
        plt.show()

# %% [markdown]
# ## face

# %%
root_folder = '/raid/xiaoyuz1/clip_model_checkpoint'
f1 = os.path.join(root_folder, "face/lr1e5_35.pickle")
f2 = os.path.join(root_folder, "all/lr1e5_12.pickle")
f3 = os.path.join(root_folder, "angel/lr1e5_20.pickle")

# %%
torch_path_name = os.path.join(root_folder, "face/lr1e5_35.pt")
acc_path_name = os.path.join(root_folder, "face/lr1e5_35.pickle")

final_accs, preds1, gts1 = None,None,None
with open(acc_path_name, 'rb') as f:
    _, final_accs, preds1, gts1 = pickle.load(f)

torch_path_name = os.path.join(root_folder, "all/lr1e5_12.pt")
acc_path_name = os.path.join(root_folder, "all/lr1e5_12.pickle")

final_accs, preds2, gts2 = None,None,None
with open(acc_path_name, 'rb') as f:
    _, final_accs, preds2, gts2 = pickle.load(f)

# torch_path_name = os.path.join(root_folder, "angel/lr1e5_20.pt")
# acc_path_name = os.path.join(root_folder, "angel/lr1e5_20.pickle")

# %%
cat = 'face'
split = 'test'

df_cat = dfp[(dfp['category'] == cat) & (dfp['split'] == split)]
df_cat = df_cat.reset_index(drop=True)

all_pair_df1 = rd.all_pair_combination(
    df_cat, wrong_rows=get_wrong(preds1[split][cat], gts1[split][cat]))
all_pair_df2 = rd.all_pair_combination(
    df_cat, wrong_rows=get_wrong(preds2[split][cat], gts2[split][cat]))

# %%
all_pair_df1[(all_pair_df1['word1'].isin(['spiky','spikey'])) | (all_pair_df1['word2'] .isin(['spiky','spikey']))]
# Out:
#        word1    word2  total_occurrence  correct#  correct% correct_row_idx  \
# 320    spiky  stringy                 1         1       1.0           [475]
# 454   spikey   droopy                 1         1       1.0           [410]
# 455   spikey     long                 1         1       1.0           [410]
# 1073  length    spiky                 1         1       1.0            [95]
# 1075  medium    spiky                 1         1       1.0            [95]
# 1077   thick    spiky                 1         1       1.0            [95]
# 1140   messy   spikey                 1         0       0.0              []
# 1141    flat   spikey                 1         0       0.0              []
# 1181   spiky    short                 1         1       1.0            [40]
# 1256   spiky     thin                 1         0       0.0              []
# 1268   spiky     long                 1         1       1.0             [0]
#
#      incorrect_row_idx
# 320                 []
# 454                 []
# 455                 []
# 1073                []
# 1075                []
# 1077                []
# 1140              [56]
# 1141              [56]
# 1181                []
# 1256               [8]
# 1268                []

# %%
all_pair_df2[(all_pair_df2['word1'].isin(['spiky','spikey'])) | (all_pair_df2['word2'] .isin(['spiky','spikey']))]
# Out:
#        word1    word2  total_occurrence  correct#  correct% correct_row_idx  \
# 320    spiky  stringy                 1         1       1.0           [475]
# 454   spikey   droopy                 1         1       1.0           [410]
# 455   spikey     long                 1         1       1.0           [410]
# 1073  length    spiky                 1         1       1.0            [95]
# 1075  medium    spiky                 1         1       1.0            [95]
# 1077   thick    spiky                 1         1       1.0            [95]
# 1140   messy   spikey                 1         0       0.0              []
# 1141    flat   spikey                 1         0       0.0              []
# 1181   spiky    short                 1         0       0.0              []
# 1256   spiky     thin                 1         1       1.0             [8]
# 1268   spiky     long                 1         0       0.0              []
#
#      incorrect_row_idx
# 320                 []
# 454                 []
# 455                 []
# 1073                []
# 1075                []
# 1077                []
# 1140              [56]
# 1141              [56]
# 1181              [40]
# 1256                []
# 1268               [0]

# %%
dfp[dfp.no_punc_1.apply(lambda x: ('spiky' in x) or ('spikey' in x))]
# Out:
#       image_1  image_2       worker_id  part category   time  \
# 18        592      453  A2JDYN6QM8M5UN     4     face  117.4
# 73        402        3  A1PTH9KTRO06EG     4     face   69.2
# 83         59      221  A272X64FOZFYLB     4     face  190.0
# 203       192      284   AHYTT3T8W9Y9Y     4     face  210.4
# 223       688      148  A2NAKIXS3DVGAA     4     face   80.6
# 363       516      227  A1PTH9KTRO06EG     4     face  714.2
# 368       100      505   APGX2WZ59OWDN     4     face  335.0
# 473       552      166  A2NAKIXS3DVGAA     4     face  294.8
# 876        48      702  A272X64FOZFYLB     0     face  302.2
# 1931      474       11   APGX2WZ59OWDN     4     face  170.6
# 1942      126      182   AHYTT3T8W9Y9Y     4     face  245.8
# 1972      688      129  A2541C8MY0BYV3     4     face  244.0
# 2315      460      193  A3UV55HC87DO9C     4     face  307.6
# 2573       98      209  A2541C8MY0BYV3     7    angel  468.8
# 2592      275      536   AHYTT3T8W9Y9Y     7    angel  197.0
# 3308      163      198   APGX2WZ59OWDN     7    angel  133.0
# 3431      393      586  A2NAKIXS3DVGAA     7    angel  172.2
# 3436      469      565  A2541C8MY0BYV3     7    angel  325.2
# 3438      462      685  A2541C8MY0BYV3     7    angel  325.2
# 4075       42      784   AWVLT2L5AP873     7    angel   90.6
# 4220      573      571   AWVLT2L5AP873     7    angel  118.2
# 4341      364       93  A1DMXEJGJY02E1     7    angel   80.6
# 4607      336      482  A1DMXEJGJY02E1     7    angel  680.4
# 4793      227      779   APGX2WZ59OWDN     7    angel  676.2
# 4888      275      111  A272X64FOZFYLB     7    angel   55.2
# 5250      616      486  A2NAKIXS3DVGAA     7    angel  319.6
# 5481      427      641   APGX2WZ59OWDN     7    angel  673.6
#
#                                                folder  \
# 18      /raid/xiaoyuz1/amazon_turk/2022_03_21_release
# 73      /raid/xiaoyuz1/amazon_turk/2022_03_21_release
# 83      /raid/xiaoyuz1/amazon_turk/2022_03_21_release
# 203     /raid/xiaoyuz1/amazon_turk/2022_03_21_release
# 223     /raid/xiaoyuz1/amazon_turk/2022_03_21_release
# 363     /raid/xiaoyuz1/amazon_turk/2022_03_22_release
# 368     /raid/xiaoyuz1/amazon_turk/2022_03_22_release
# 473     /raid/xiaoyuz1/amazon_turk/2022_03_22_release
# 876     /raid/xiaoyuz1/amazon_turk/2022_03_23_release
# 1931    /raid/xiaoyuz1/amazon_turk/2022_04_04_release
# 1942    /raid/xiaoyuz1/amazon_turk/2022_04_04_release
# 1972    /raid/xiaoyuz1/amazon_turk/2022_04_04_release
# 2315  /raid/xiaoyuz1/amazon_turk/2022_04_04_release_2
# 2573    /raid/xiaoyuz1/amazon_turk/2022_04_05_release
# 2592    /raid/xiaoyuz1/amazon_turk/2022_04_05_release
# 3308    /raid/xiaoyuz1/amazon_turk/2022_04_06_release
# 3431    /raid/xiaoyuz1/amazon_turk/2022_04_06_release
# 3436    /raid/xiaoyuz1/amazon_turk/2022_04_06_release
# 3438    /raid/xiaoyuz1/amazon_turk/2022_04_06_release
# 4075  /raid/xiaoyuz1/amazon_turk/2022_04_06_release_2
# 4220  /raid/xiaoyuz1/amazon_turk/2022_04_06_release_2
# 4341  /raid/xiaoyuz1/amazon_turk/2022_04_06_release_2
# 4607  /raid/xiaoyuz1/amazon_turk/2022_04_06_release_2
# 4793  /raid/xiaoyuz1/amazon_turk/2022_04_06_release_3
# 4888  /raid/xiaoyuz1/amazon_turk/2022_04_06_release_3
# 5250  /raid/xiaoyuz1/amazon_turk/2022_04_06_release_3
# 5481  /raid/xiaoyuz1/amazon_turk/2022_04_06_release_3
#
#                                           text_1  \
# 18                                         spiky
# 73                                         spiky
# 83                              spiky zig-zagged
# 203                                        spiky
# 223                                        spiky
# 363                                        spiky
# 368                                        spiky
# 473                                   tall spiky
# 876                               spiky circular
# 1931                                       spiky
# 1942                                       spiky
# 1972                                      spikey
# 2315                                       spiky
# 2573                                      spikey
# 2592                                spiky, sharp
# 3308                                       spiky
# 3431  straight line-shaped and spiky club-shaped
# 3436                                      spikey
# 3438                               sharp, spikey
# 4075                          asymmetrical spiky
# 4220                               spiky, flared
# 4341                                       spiky
# 4607                                       spiky
# 4793                                       spiky
# 4888                           spiky, zig-zagged
# 5250                      spiky rotated U-shaped
# 5481                                       spiky
#
#                               text_2  \
# 18                              long
# 73                              thin
# 83                          straight
# 203             fine, thin, straight
# 223                            short
# 363                             flat
# 368                      rounded-top
# 473                       hat-shaped
# 876                  smooth circular
# 1931                         flowing
# 1942                  thin, straight
# 1972                     long droopy
# 2315                         stringy
# 2573                        box-like
# 2592                    heart-shaped
# 3308                          smooth
# 3431                    knife-shaped
# 3436                 rounded, curved
# 3438                         angular
# 4075          thick, crescent-shaped
# 4220              droopy, ghost-like
# 4341                       half-moon
# 4607               downturned spikey
# 4793                         rounded
# 4888  irregular quadrilateral-shaped
# 5250         spiky candy-cane-shaped
# 5481                           bumpy
#
#                                           tokenized_1  \
# 18                                          ['spiky']
# 73                                          ['spiky']
# 83                    ['spiky', 'zig', '-', 'zagged']
# 203                                         ['spiky']
# 223                                         ['spiky']
# 363                                         ['spiky']
# 368                                         ['spiky']
# 473                                 ['tall', 'spiky']
# 876                             ['spiky', 'circular']
# 1931                                        ['spiky']
# 1942                                        ['spiky']
# 1972                                       ['spikey']
# 2315                                        ['spiky']
# 2573                                       ['spikey']
# 2592                          ['spiky', ',', 'sharp']
# 3308                                        ['spiky']
# 3431  ['straight', 'line', '-', 'spiky', 'club', '-']
# 3436                                       ['spikey']
# 3438                         ['sharp', ',', 'spikey']
# 4075                        ['asymmetrical', 'spiky']
# 4220                          ['spiky', ',', 'flare']
# 4341                                        ['spiky']
# 4607                                        ['spiky']
# 4793                                        ['spiky']
# 4888             ['spiky', ',', 'zig', '-', 'zagged']
# 5250                    ['spiky', 'rotate', 'u', '-']
# 5481                                        ['spiky']
#
#                                               lower_1  \
# 18                                          ['spiky']
# 73                                          ['spiky']
# 83                    ['spiky', 'zig', '-', 'zagged']
# 203                                         ['spiky']
# 223                                         ['spiky']
# 363                                         ['spiky']
# 368                                         ['spiky']
# 473                                 ['tall', 'spiky']
# 876                             ['spiky', 'circular']
# 1931                                        ['spiky']
# 1942                                        ['spiky']
# 1972                                       ['spikey']
# 2315                                        ['spiky']
# 2573                                       ['spikey']
# 2592                          ['spiky', ',', 'sharp']
# 3308                                        ['spiky']
# 3431  ['straight', 'line', '-', 'spiky', 'club', '-']
# 3436                                       ['spikey']
# 3438                         ['sharp', ',', 'spikey']
# 4075                        ['asymmetrical', 'spiky']
# 4220                          ['spiky', ',', 'flare']
# 4341                                        ['spiky']
# 4607                                        ['spiky']
# 4793                                        ['spiky']
# 4888             ['spiky', ',', 'zig', '-', 'zagged']
# 5250                    ['spiky', 'rotate', 'u', '-']
# 5481                                        ['spiky']
#
#                           no_punc_1             no_punc_str_1  \
# 18                          [spiky]                     spiky
# 73                          [spiky]                     spiky
# 83             [spiky, zig, zagged]          spiky zig zagged
# 203                         [spiky]                     spiky
# 223                         [spiky]                     spiky
# 363                         [spiky]                     spiky
# 368                         [spiky]                     spiky
# 473                   [tall, spiky]                tall spiky
# 876               [spiky, circular]            spiky circular
# 1931                        [spiky]                     spiky
# 1942                        [spiky]                     spiky
# 1972                       [spikey]                    spikey
# 2315                        [spiky]                     spiky
# 2573                       [spikey]                    spikey
# 2592                 [spiky, sharp]               spiky sharp
# 3308                        [spiky]                     spiky
# 3431  [straight, line, spiky, club]  straight line spiky club
# 3436                       [spikey]                    spikey
# 3438                [sharp, spikey]              sharp spikey
# 4075          [asymmetrical, spiky]        asymmetrical spiky
# 4220                 [spiky, flare]               spiky flare
# 4341                        [spiky]                     spiky
# 4607                        [spiky]                     spiky
# 4793                        [spiky]                     spiky
# 4888           [spiky, zig, zagged]          spiky zig zagged
# 5250             [spiky, rotate, u]            spiky rotate u
# 5481                        [spiky]                     spiky
#
#                                  tokenized_2  \
# 18                                  ['long']
# 73                                  ['thin']
# 83                              ['straight']
# 203   ['fine', ',', 'thin', ',', 'straight']
# 223                                ['short']
# 363                                 ['flat']
# 368                  ['rounded', '-', 'top']
# 473                             ['hat', '-']
# 876                   ['smooth', 'circular']
# 1931                                ['flow']
# 1942               ['thin', ',', 'straight']
# 1972                      ['long', 'droopy']
# 2315                             ['stringy']
# 2573                            ['box', '-']
# 2592                          ['heart', '-']
# 3308                              ['smooth']
# 3431                          ['knife', '-']
# 3436               ['rounded', ',', 'curve']
# 3438                             ['angular']
# 4075         ['thick', ',', 'crescent', '-']
# 4220           ['droopy', ',', 'ghost', '-']
# 4341                   ['half', '-', 'moon']
# 4607                 ['downturne', 'spikey']
# 4793                             ['rounded']
# 4888     ['irregular', 'quadrilateral', '-']
# 5250    ['spiky', 'candy', '-', 'cane', '-']
# 5481                               ['bumpy']
#
#                                      lower_2                   no_punc_2  \
# 18                                  ['long']                      [long]
# 73                                  ['thin']                      [thin]
# 83                              ['straight']                  [straight]
# 203   ['fine', ',', 'thin', ',', 'straight']      [fine, thin, straight]
# 223                                ['short']                     [short]
# 363                                 ['flat']                      [flat]
# 368                  ['rounded', '-', 'top']              [rounded, top]
# 473                             ['hat', '-']                       [hat]
# 876                   ['smooth', 'circular']          [smooth, circular]
# 1931                                ['flow']                      [flow]
# 1942               ['thin', ',', 'straight']            [thin, straight]
# 1972                      ['long', 'droopy']              [long, droopy]
# 2315                             ['stringy']                   [stringy]
# 2573                            ['box', '-']                       [box]
# 2592                          ['heart', '-']                     [heart]
# 3308                              ['smooth']                    [smooth]
# 3431                          ['knife', '-']                     [knife]
# 3436               ['rounded', ',', 'curve']            [rounded, curve]
# 3438                             ['angular']                   [angular]
# 4075         ['thick', ',', 'crescent', '-']           [thick, crescent]
# 4220           ['droopy', ',', 'ghost', '-']             [droopy, ghost]
# 4341                   ['half', '-', 'moon']                [half, moon]
# 4607                 ['downturne', 'spikey']         [downturne, spikey]
# 4793                             ['rounded']                   [rounded]
# 4888     ['irregular', 'quadrilateral', '-']  [irregular, quadrilateral]
# 5250    ['spiky', 'candy', '-', 'cane', '-']        [spiky, candy, cane]
# 5481                               ['bumpy']                     [bumpy]
#
#                 no_punc_str_2  split
# 18                       long   test
# 73                       thin   test
# 83                   straight  train
# 203        fine thin straight    dev
# 223                     short   test
# 363                      flat  train
# 368               rounded top    dev
# 473                       hat  train
# 876           smooth circular  train
# 1931                     flow  train
# 1942            thin straight  train
# 1972              long droopy   test
# 2315                  stringy   test
# 2573                      box   test
# 2592                    heart   test
# 3308                   smooth  train
# 3431                    knife  train
# 3436            rounded curve  train
# 3438                  angular  train
# 4075           thick crescent  train
# 4220             droopy ghost   test
# 4341                half moon  train
# 4607         downturne spikey  train
# 4793                  rounded   test
# 4888  irregular quadrilateral  train
# 5250         spiky candy cane  train
# 5481                    bumpy  train
