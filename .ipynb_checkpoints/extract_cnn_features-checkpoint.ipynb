# %%
import os
import torch
import torchvision.models as models
import torchvision.transforms as transforms
import numpy as np
import PIL
import torch.nn as nn
from tqdm import tqdm
from torch.utils.data import DataLoader

# %%
import sys
sys.path.append("/home/xiaoyuz1/multigraph_transformer")
from dataloader.QuickdrawDataset import *

# %%
cnn_train_data_labels = {}
with open('/raid/xiaoyuz1/sketch_datasets/data_4_cnnbaselines/tiny_train_set.txt', 'r') as f:
    lines = f.readlines()
    lines = [line.strip() for line in lines]
    for line in lines:
        k = line.split(" ")[0].split("/")[0]
        v = int(line.split(" ")[1])
        cnn_train_data_labels[k] = v

# %%
cnn_train_data_labels
# Out:
# {'banana': 16,
#  'house': 156,
#  'spider': 279,
#  'hourglass': 155,
#  'shark': 260,
#  'bat': 23,
#  'oven': 206,
#  'fish': 119,
#  'bucket': 48,
#  'line': 176,
#  'moustache': 195,
#  'ice_cream': 159,
#  'ceiling_fan': 68,
#  'train': 322,
#  't-shirt': 304,
#  'stairs': 285,
#  'telephone': 308,
#  'arm': 12,
#  'star': 286,
#  'underwear': 329,
#  'penguin': 221,
#  'drill': 100,
#  'firetruck': 118,
#  'chandelier': 72,
#  'violin': 332,
#  'wristwatch': 341,
#  'microphone': 187,
#  'ear': 104,
#  'parrot': 215,
#  'table': 305,
#  'hat': 142,
#  'beach': 25,
#  'speedboat': 278,
#  'pig': 225,
#  'rainbow': 242,
#  'horse': 150,
#  'pliers': 229,
#  'raccoon': 239,
#  'ant': 9,
#  'pillow': 226,
#  'sheep': 261,
#  'elephant': 106,
#  'picture_frame': 224,
#  'foot': 126,
#  'jail': 161,
#  'snake': 272,
#  'dragon': 98,
#  'owl': 207,
#  'eye': 109,
#  'book': 38,
#  'paper_clip': 213,
#  'bench': 31,
#  'fire_hydrant': 116,
#  'shorts': 263,
#  'megaphone': 185,
#  'spreadsheet': 281,
#  'monkey': 189,
#  'waterslide': 335,
#  'duck': 102,
#  'strawberry': 293,
#  'lighthouse': 174,
#  'popsicle': 233,
#  'cactus': 53,
#  'roller_coaster': 248,
#  'animal_migration': 8,
#  'bracelet': 42,
#  'grass': 136,
#  'potato': 235,
#  'toaster': 313,
#  'washing_machine': 333,
#  'marker': 183,
#  'triangle': 324,
#  'police_car': 230,
#  'mouth': 196,
#  'mug': 197,
#  'finger': 115,
#  'hockey_stick': 149,
#  'peas': 219,
#  'squirrel': 284,
#  'swan': 299,
#  'microwave': 188,
#  'crown': 88,
#  'cannon': 62,
#  'donut': 96,
#  'camouflage': 59,
#  'tennis_racquet': 310,
#  'carrot': 65,
#  'map': 182,
#  'palm_tree': 210,
#  'bed': 28,
#  'scorpion': 256,
#  'house_plant': 157,
#  'motorbike': 192,
#  'steak': 287,
#  'bus': 50,
#  'piano': 222,
#  'broccoli': 46,
#  'stop_sign': 291,
#  'wine_bottle': 339,
#  'flying_saucer': 125,
#  'canoe': 63,
#  'whale': 336,
#  'laptop': 169,
#  'hurricane': 158,
#  'lion': 177,
#  'rifle': 246,
#  'leaf': 170,
#  'hockey_puck': 148,
#  'ocean': 202,
#  'bottlecap': 40,
#  'mosquito': 191,
#  'sword': 302,
#  'umbrella': 328,
#  'scissors': 255,
#  'binoculars': 33,
#  'diving_board': 93,
#  'frying_pan': 129,
#  'The_Mona_Lisa': 2,
#  'suitcase': 297,
#  'moon': 190,
#  'school_bus': 254,
#  'fireplace': 117,
#  'tractor': 320,
#  'elbow': 105,
#  'tiger': 312,
#  'cloud': 77,
#  'panda': 211,
#  'mushroom': 198,
#  'radio': 240,
#  'calendar': 56,
#  'coffee_cup': 78,
#  'bird': 34,
#  'rollerskates': 249,
#  'bowtie': 41,
#  'teddy-bear': 307,
#  'bicycle': 32,
#  'hand': 140,
#  'square': 282,
#  'ambulance': 6,
#  'vase': 331,
#  'fork': 127,
#  'boomerang': 39,
#  'pear': 218,
#  'submarine': 296,
#  'axe': 14,
#  'cake': 54,
#  'sock': 277,
#  'kangaroo': 162,
#  'van': 330,
#  'fan': 112,
#  'bathtub': 24,
#  'eyeglasses': 110,
#  'yoga': 342,
#  'snail': 271,
#  'streetlight': 294,
#  'flashlight': 121,
#  'rabbit': 238,
#  'trombone': 325,
#  'parachute': 214,
#  'campfire': 60,
#  'onion': 205,
#  'helicopter': 145,
#  'soccer_ball': 276,
#  'light_bulb': 172,
#  'sweater': 300,
#  'toe': 314,
#  'power_outlet': 236,
#  'pants': 212,
#  'bridge': 45,
#  'shoe': 262,
#  'guitar': 137,
#  'cow': 84,
#  'stitches': 290,
#  'hot_air_balloon': 152,
#  'snowman': 275,
#  'compass': 79,
#  'syringe': 303,
#  'zigzag': 344,
#  'sea_turtle': 258,
#  'calculator': 55,
#  'anvil': 10,
#  'angel': 7,
#  'basket': 21,
#  'broom': 47,
#  'cup': 90,
#  'mouse': 194,
#  'fence': 114,
#  'zebra': 343,
#  'aircraft_carrier': 3,
#  'stereo': 288,
#  'feather': 113,
#  'drums': 101,
#  'flower': 124,
#  'sleeping_bag': 269,
#  'lighter': 173,
#  'airplane': 4,
#  'mailbox': 181,
#  'see_saw': 259,
#  'harp': 141,
#  'peanut': 217,
#  'headphones': 143,
#  'clock': 76,
#  'pizza': 228,
#  'helmet': 146,
#  'blueberry': 37,
#  'leg': 171,
#  'dolphin': 95,
#  'passport': 216,
#  'remote_control': 244,
#  'bread': 44,
#  'circle': 74,
#  'swing_set': 301,
#  'lobster': 179,
#  'bear': 26,
#  'envelope': 107,
#  'lipstick': 178,
#  'stethoscope': 289,
#  'golf_club': 134,
#  'hot_dog': 153,
#  'candle': 61,
#  'flamingo': 120,
#  'castle': 66,
#  'postcard': 234,
#  'asparagus': 13,
#  'ladder': 167,
#  'alarm_clock': 5,
#  'tree': 323,
#  'cookie': 81,
#  'string_bean': 295,
#  'door': 97,
#  'car': 64,
#  'paint_can': 208,
#  'pineapple': 227,
#  'trumpet': 327,
#  'backpack': 15,
#  'saxophone': 253,
#  'camel': 57,
#  'chair': 71,
#  'garden_hose': 131,
#  'church': 73,
#  'lantern': 168,
#  'giraffe': 132,
#  'face': 111,
#  'baseball_bat': 20,
#  'matches': 184,
#  'dishwasher': 92,
#  'smiley_face': 270,
#  'tooth': 316,
#  'toothbrush': 317,
#  'sailboat': 250,
#  'basketball': 22,
#  'floor_lamp': 123,
#  'diamond': 91,
#  'snorkel': 273,
#  'skull': 267,
#  'pond': 231,
#  'hot_tub': 154,
#  'jacket': 160,
#  'dog': 94,
#  'pickup_truck': 223,
#  'snowflake': 274,
#  'butterfly': 52,
#  'watermelon': 334,
#  'bush': 51,
#  'mermaid': 186,
#  'nail': 199,
#  'keyboard': 164,
#  'screwdriver': 257,
#  'garden': 130,
#  'toilet': 315,
#  'skyscraper': 268,
#  'necklace': 200,
#  'saw': 252,
#  'hospital': 151,
#  'camera': 58,
#  'wheel': 337,
#  'frog': 128,
#  'clarinet': 75,
#  'sun': 298,
#  'tornado': 319,
#  'octagon': 203,
#  'belt': 30,
#  'bandage': 17,
#  'key': 163,
#  'goatee': 133,
#  'tent': 311,
#  'stove': 292,
#  'rake': 243,
#  'cat': 67,
#  'hexagon': 147,
#  'hedgehog': 144,
#  'traffic_light': 321,
#  'apple': 11,
#  'wine_glass': 340,
#  'octopus': 204,
#  'skateboard': 266,
#  'rain': 241,
#  'knife': 166,
#  'pool': 232,
#  'lightning': 175,
#  'nose': 201,
#  'river': 247,
#  'sandwich': 251,
#  'cruise_ship': 89,
#  'eraser': 108,
#  'hammer': 139,
#  'mountain': 193,
#  'cooler': 82,
#  'grapes': 135,
#  'cell_phone': 69,
#  'barn': 18,
#  'knee': 165,
#  'baseball': 19,
#  'cello': 70,
#  'toothpaste': 318,
#  'shovel': 264,
#  'birthday_cake': 35,
#  'pencil': 220,
#  'The_Great_Wall_of_China': 1,
#  'flip_flops': 122,
#  'crab': 85,
#  'dumbbell': 103,
#  'truck': 326,
#  'couch': 83,
#  'squiggle': 283,
#  'bulldozer': 49,
#  'purse': 237,
#  'hamburger': 138,
#  'beard': 27,
#  'bee': 29,
#  'brain': 43,
#  'crocodile': 87,
#  'dresser': 99,
#  'windmill': 338,
#  'The_Eiffel_Tower': 0,
#  'computer': 80,
#  'rhinoceros': 245,
#  'lollipop': 180,
#  'crayon': 86,
#  'teapot': 306,
#  'spoon': 280,
#  'blackberry': 36,
#  'television': 309,
#  'sink': 265,
#  'paintbrush': 209}

# %%
folder = "/raid/xiaoyuz1/sketch_datasets/spg/drill"
sub_files = os.listdir(folder)
print("Total number of images: ", len(sub_files))
# Out:
# Total number of images:  801

# %%
# test_img = PIL.Image.open("/raid/xiaoyuz1/sketch_datasets/data_4_cnnbaselines/tiny_train_set/face/face_1538.png")
# print(np.asarray(test_img).shape)
# np.unique(np.asarray(test_img), return_counts=True)

# %%
# img_path = os.path.join(folder, sub_files[0])
# sketch = PIL.Image.open(img_path, 'r')

# import PIL.ImageOps


# if(len(np.asarray(sketch).shape) < 3):
#     sketch = sketch.convert(mode='RGB')
# sketch = PIL.ImageOps.invert( sketch )

# print(np.asarray(sketch).shape)
# np.unique(np.asarray(sketch), return_counts=True)

# %%
img_path = os.path.join(folder, sub_files[10])
pimg = PIL.Image.open(img_path)
pimg
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=L size=256x256 at 0x7F0FE0072280>

# %%
label = cnn_train_data_labels['drill']
label
# Out:
# 100

# %%
sketch_list_fname = os.path.join(folder, 'annotation.txt')

with open(sketch_list_fname, 'w+') as f:
    for file in sub_files:
        if not file.endswith(".png"):
            continue
        line = '{} {}\n'.format(file, label)
        f.write(line)

# %%
transform_train = transforms.Compose([
    # transforms.RandomHorizontalFlip(),
    transforms.Resize(299),
    transforms.ToTensor()
])
transform_val = transforms.Compose([
    transforms.Resize(299),
    transforms.ToTensor()
])
feat_dataset = QuickdrawDataset(
    folder, 
    sketch_list_fname, 
    transform_val,
    flip=True)

feat_loader = DataLoader(
    feat_dataset, 
    batch_size=64, 
    shuffle=False, 
    num_workers=12)

# %%
print(feat_dataset[0][0].shape)
# Out:
# torch.Size([3, 299, 299])

# %%
model_ckpt_folder = os.path.join(
    "/home/xiaoyuz1/multigraph_transformer/baselines/cnn_baselines",
    "experimental_results/inceptionv3_001/checkpoints"
)

# %%
np.asarray(os.listdir(model_ckpt_folder))
# Out:
# array(['inceptionv3_001_net_epoch1', 'inceptionv3_001_net_epoch12',
#        'inceptionv3_001_net_epoch2', 'inceptionv3_001_net_epoch11',
#        'inceptionv3_001_net_epoch5', 'inceptionv3_001_net_epoch7',
#        'inceptionv3_001_net_epoch14', 'inceptionv3_001_net_epoch17',
#        'inceptionv3_001_net_epoch3', 'inceptionv3_001_net_epoch4',
#        'inceptionv3_001_net_epoch16', 'inceptionv3_001_net_epoch9',
#        'inceptionv3_001_net_epoch6', 'inceptionv3_001_net_epoch10',
#        'inceptionv3_001_net_epoch8', 'inceptionv3_001_net_epoch13',
#        'inceptionv3_001_net_epoch15'], dtype='<U27')

# %%
model_path = os.path.join(model_ckpt_folder, 'inceptionv3_001_net_epoch17')

# %%
model = models.inception_v3(num_classes = 345)
# Out:
# /home/xiaoyuz1/anaconda3/envs/clipdraw/lib/python3.8/site-packages/torchvision/models/inception.py:75: FutureWarning: The default weight initialization of inception_v3 will be changed in future releases of torchvision. If you wish to keep the old behavior (which leads to long initialization times due to scipy/scipy#11299), please set init_weights=True.
#   warnings.warn('The default weight initialization of inception_v3 will be changed in future releases of '

# %%
model_dict = model.state_dict()
pretrained_dict = torch.load(model_path)['network']

for k in model_dict.keys():
    if k not in pretrained_dict:
        print(k)

pretrained_dict_filtered = {k: v for k, v in pretrained_dict.items() if k in model_dict}
model_dict.update(pretrained_dict) 
model.load_state_dict(pretrained_dict)
# Out:
# <All keys matched successfully>

# %%
# net = nn.Sequential(*list(model.children())[:-3])

# %%
class MyInceptionFeatureExtractor(nn.Module):
    def __init__(self, inception, transform_input=False):
        super(MyInceptionFeatureExtractor, self).__init__()
        self.transform_input = transform_input
        
        self.my_Conv2d_1a_3x3 = inception.Conv2d_1a_3x3
        self.my_Conv2d_2a_3x3 = inception.Conv2d_2a_3x3
        self.my_Conv2d_2b_3x3 = inception.Conv2d_2b_3x3
        self.my_maxpool1 = inception.maxpool1
        self.my_Conv2d_3b_1x1 = inception.Conv2d_3b_1x1
        self.my_Conv2d_4a_3x3 = inception.Conv2d_4a_3x3
        self.my_maxpool2 = inception.maxpool2
        self.my_Mixed_5b = inception.Mixed_5b
        self.my_Mixed_5c = inception.Mixed_5c
        self.my_Mixed_5d = inception.Mixed_5d
        self.my_Mixed_6a = inception.Mixed_6a
        self.my_Mixed_6b = inception.Mixed_6b
        self.my_Mixed_6c = inception.Mixed_6c
        self.my_Mixed_6d = inception.Mixed_6d
        self.my_Mixed_6e = inception.Mixed_6e
        self.my_AuxLogits = inception.AuxLogits
        self.my_Mixed_7a = inception.Mixed_7a
        self.my_Mixed_7b = inception.Mixed_7b
        self.my_Mixed_7c = inception.Mixed_7c
        
        self.avgpool = inception.avgpool
        self.fc = inception.fc

    def forward(self, x):
        if self.transform_input:
            x = x.clone()
            x[0] = x[0] * (0.229 / 0.5) + (0.485 - 0.5) / 0.5
            x[1] = x[1] * (0.224 / 0.5) + (0.456 - 0.5) / 0.5
            x[2] = x[2] * (0.225 / 0.5) + (0.406 - 0.5) / 0.5
        
        x = self.my_Conv2d_1a_3x3(x)
        x = self.my_Conv2d_2a_3x3(x)
        x = self.my_Conv2d_2b_3x3(x)
        x = self.my_maxpool1(x)
        x = self.my_Conv2d_3b_1x1(x)
        x = self.my_Conv2d_4a_3x3(x)
        x = self.my_maxpool2(x)
        
        x = self.my_Mixed_5b(x)
        x = self.my_Mixed_5c(x)
        x = self.my_Mixed_5d(x)
        
        x = self.my_Mixed_6a(x) #768, 17, 17
        x = self.my_Mixed_6b(x)
        x = self.my_Mixed_6c(x)
        x = self.my_Mixed_6d(x)
        x = self.my_Mixed_6e(x) #768, 17, 17
        
#         x = self.my_AuxLogits(x)
        
        x = self.my_Mixed_7a(x)
        x = self.my_Mixed_7b(x)
        x = self.my_Mixed_7c(x)
        
        x = self.avgpool(x)
        
#         # 299 x 299 x 3
#         x = self.Conv2d_1a_3x3(x)
#         # 149 x 149 x 32
#         x = self.Conv2d_2a_3x3(x)
#         # 147 x 147 x 32
#         x = self.Conv2d_2b_3x3(x)
#         # 147 x 147 x 64
#         x = F.max_pool2d(x, kernel_size=3, stride=2)
#         # 73 x 73 x 64
#         x = self.Conv2d_3b_1x1(x)
#         # 73 x 73 x 80
#         x = self.Conv2d_4a_3x3(x)
#         # 71 x 71 x 192
#         x = F.max_pool2d(x, kernel_size=3, stride=2)
#         # 35 x 35 x 192
#         x = self.Mixed_5b(x)
#         # copy paste from model definition, just stopping where you want
        return x

# %%
net = MyInceptionFeatureExtractor(model)

# %%
net.cuda()
net.eval()
# Out:
# MyInceptionFeatureExtractor(
#   (my_Conv2d_1a_3x3): BasicConv2d(
#     (conv): Conv2d(3, 32, kernel_size=(3, 3), stride=(2, 2), bias=False)
#     (bn): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (my_Conv2d_2a_3x3): BasicConv2d(
#     (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), bias=False)
#     (bn): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (my_Conv2d_2b_3x3): BasicConv2d(
#     (conv): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (my_maxpool1): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (my_Conv2d_3b_1x1): BasicConv2d(
#     (conv): Conv2d(64, 80, kernel_size=(1, 1), stride=(1, 1), bias=False)
#     (bn): BatchNorm2d(80, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (my_Conv2d_4a_3x3): BasicConv2d(
#     (conv): Conv2d(80, 192, kernel_size=(3, 3), stride=(1, 1), bias=False)
#     (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (my_maxpool2): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (my_Mixed_5b): InceptionA(
#     (branch1x1): BasicConv2d(
#       (conv): Conv2d(192, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch5x5_1): BasicConv2d(
#       (conv): Conv2d(192, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(48, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch5x5_2): BasicConv2d(
#       (conv): Conv2d(48, 64, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), bias=False)
#       (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3dbl_1): BasicConv2d(
#       (conv): Conv2d(192, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3dbl_2): BasicConv2d(
#       (conv): Conv2d(64, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn): BatchNorm2d(96, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3dbl_3): BasicConv2d(
#       (conv): Conv2d(96, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn): BatchNorm2d(96, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch_pool): BasicConv2d(
#       (conv): Conv2d(192, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (my_Mixed_5c): InceptionA(
#     (branch1x1): BasicConv2d(
#       (conv): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch5x5_1): BasicConv2d(
#       (conv): Conv2d(256, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(48, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch5x5_2): BasicConv2d(
#       (conv): Conv2d(48, 64, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), bias=False)
#       (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3dbl_1): BasicConv2d(
#       (conv): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3dbl_2): BasicConv2d(
#       (conv): Conv2d(64, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn): BatchNorm2d(96, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3dbl_3): BasicConv2d(
#       (conv): Conv2d(96, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn): BatchNorm2d(96, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch_pool): BasicConv2d(
#       (conv): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (my_Mixed_5d): InceptionA(
#     (branch1x1): BasicConv2d(
#       (conv): Conv2d(288, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch5x5_1): BasicConv2d(
#       (conv): Conv2d(288, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(48, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch5x5_2): BasicConv2d(
#       (conv): Conv2d(48, 64, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), bias=False)
#       (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3dbl_1): BasicConv2d(
#       (conv): Conv2d(288, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3dbl_2): BasicConv2d(
#       (conv): Conv2d(64, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn): BatchNorm2d(96, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3dbl_3): BasicConv2d(
#       (conv): Conv2d(96, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn): BatchNorm2d(96, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch_pool): BasicConv2d(
#       (conv): Conv2d(288, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (my_Mixed_6a): InceptionB(
#     (branch3x3): BasicConv2d(
#       (conv): Conv2d(288, 384, kernel_size=(3, 3), stride=(2, 2), bias=False)
#       (bn): BatchNorm2d(384, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3dbl_1): BasicConv2d(
#       (conv): Conv2d(288, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3dbl_2): BasicConv2d(
#       (conv): Conv2d(64, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn): BatchNorm2d(96, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3dbl_3): BasicConv2d(
#       (conv): Conv2d(96, 96, kernel_size=(3, 3), stride=(2, 2), bias=False)
#       (bn): BatchNorm2d(96, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (my_Mixed_6b): InceptionC(
#     (branch1x1): BasicConv2d(
#       (conv): Conv2d(768, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7_1): BasicConv2d(
#       (conv): Conv2d(768, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7_2): BasicConv2d(
#       (conv): Conv2d(128, 128, kernel_size=(1, 7), stride=(1, 1), padding=(0, 3), bias=False)
#       (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7_3): BasicConv2d(
#       (conv): Conv2d(128, 192, kernel_size=(7, 1), stride=(1, 1), padding=(3, 0), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7dbl_1): BasicConv2d(
#       (conv): Conv2d(768, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7dbl_2): BasicConv2d(
#       (conv): Conv2d(128, 128, kernel_size=(7, 1), stride=(1, 1), padding=(3, 0), bias=False)
#       (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7dbl_3): BasicConv2d(
#       (conv): Conv2d(128, 128, kernel_size=(1, 7), stride=(1, 1), padding=(0, 3), bias=False)
#       (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7dbl_4): BasicConv2d(
#       (conv): Conv2d(128, 128, kernel_size=(7, 1), stride=(1, 1), padding=(3, 0), bias=False)
#       (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7dbl_5): BasicConv2d(
#       (conv): Conv2d(128, 192, kernel_size=(1, 7), stride=(1, 1), padding=(0, 3), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch_pool): BasicConv2d(
#       (conv): Conv2d(768, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (my_Mixed_6c): InceptionC(
#     (branch1x1): BasicConv2d(
#       (conv): Conv2d(768, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7_1): BasicConv2d(
#       (conv): Conv2d(768, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(160, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7_2): BasicConv2d(
#       (conv): Conv2d(160, 160, kernel_size=(1, 7), stride=(1, 1), padding=(0, 3), bias=False)
#       (bn): BatchNorm2d(160, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7_3): BasicConv2d(
#       (conv): Conv2d(160, 192, kernel_size=(7, 1), stride=(1, 1), padding=(3, 0), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7dbl_1): BasicConv2d(
#       (conv): Conv2d(768, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(160, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7dbl_2): BasicConv2d(
#       (conv): Conv2d(160, 160, kernel_size=(7, 1), stride=(1, 1), padding=(3, 0), bias=False)
#       (bn): BatchNorm2d(160, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7dbl_3): BasicConv2d(
#       (conv): Conv2d(160, 160, kernel_size=(1, 7), stride=(1, 1), padding=(0, 3), bias=False)
#       (bn): BatchNorm2d(160, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7dbl_4): BasicConv2d(
#       (conv): Conv2d(160, 160, kernel_size=(7, 1), stride=(1, 1), padding=(3, 0), bias=False)
#       (bn): BatchNorm2d(160, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7dbl_5): BasicConv2d(
#       (conv): Conv2d(160, 192, kernel_size=(1, 7), stride=(1, 1), padding=(0, 3), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch_pool): BasicConv2d(
#       (conv): Conv2d(768, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (my_Mixed_6d): InceptionC(
#     (branch1x1): BasicConv2d(
#       (conv): Conv2d(768, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7_1): BasicConv2d(
#       (conv): Conv2d(768, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(160, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7_2): BasicConv2d(
#       (conv): Conv2d(160, 160, kernel_size=(1, 7), stride=(1, 1), padding=(0, 3), bias=False)
#       (bn): BatchNorm2d(160, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7_3): BasicConv2d(
#       (conv): Conv2d(160, 192, kernel_size=(7, 1), stride=(1, 1), padding=(3, 0), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7dbl_1): BasicConv2d(
#       (conv): Conv2d(768, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(160, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7dbl_2): BasicConv2d(
#       (conv): Conv2d(160, 160, kernel_size=(7, 1), stride=(1, 1), padding=(3, 0), bias=False)
#       (bn): BatchNorm2d(160, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7dbl_3): BasicConv2d(
#       (conv): Conv2d(160, 160, kernel_size=(1, 7), stride=(1, 1), padding=(0, 3), bias=False)
#       (bn): BatchNorm2d(160, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7dbl_4): BasicConv2d(
#       (conv): Conv2d(160, 160, kernel_size=(7, 1), stride=(1, 1), padding=(3, 0), bias=False)
#       (bn): BatchNorm2d(160, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7dbl_5): BasicConv2d(
#       (conv): Conv2d(160, 192, kernel_size=(1, 7), stride=(1, 1), padding=(0, 3), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch_pool): BasicConv2d(
#       (conv): Conv2d(768, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (my_Mixed_6e): InceptionC(
#     (branch1x1): BasicConv2d(
#       (conv): Conv2d(768, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7_1): BasicConv2d(
#       (conv): Conv2d(768, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7_2): BasicConv2d(
#       (conv): Conv2d(192, 192, kernel_size=(1, 7), stride=(1, 1), padding=(0, 3), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7_3): BasicConv2d(
#       (conv): Conv2d(192, 192, kernel_size=(7, 1), stride=(1, 1), padding=(3, 0), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7dbl_1): BasicConv2d(
#       (conv): Conv2d(768, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7dbl_2): BasicConv2d(
#       (conv): Conv2d(192, 192, kernel_size=(7, 1), stride=(1, 1), padding=(3, 0), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7dbl_3): BasicConv2d(
#       (conv): Conv2d(192, 192, kernel_size=(1, 7), stride=(1, 1), padding=(0, 3), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7dbl_4): BasicConv2d(
#       (conv): Conv2d(192, 192, kernel_size=(7, 1), stride=(1, 1), padding=(3, 0), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7dbl_5): BasicConv2d(
#       (conv): Conv2d(192, 192, kernel_size=(1, 7), stride=(1, 1), padding=(0, 3), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch_pool): BasicConv2d(
#       (conv): Conv2d(768, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (my_AuxLogits): InceptionAux(
#     (conv0): BasicConv2d(
#       (conv): Conv2d(768, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (conv1): BasicConv2d(
#       (conv): Conv2d(128, 768, kernel_size=(5, 5), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(768, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (fc): Linear(in_features=768, out_features=345, bias=True)
#   )
#   (my_Mixed_7a): InceptionD(
#     (branch3x3_1): BasicConv2d(
#       (conv): Conv2d(768, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3_2): BasicConv2d(
#       (conv): Conv2d(192, 320, kernel_size=(3, 3), stride=(2, 2), bias=False)
#       (bn): BatchNorm2d(320, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7x3_1): BasicConv2d(
#       (conv): Conv2d(768, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7x3_2): BasicConv2d(
#       (conv): Conv2d(192, 192, kernel_size=(1, 7), stride=(1, 1), padding=(0, 3), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7x3_3): BasicConv2d(
#       (conv): Conv2d(192, 192, kernel_size=(7, 1), stride=(1, 1), padding=(3, 0), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7x3_4): BasicConv2d(
#       (conv): Conv2d(192, 192, kernel_size=(3, 3), stride=(2, 2), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (my_Mixed_7b): InceptionE(
#     (branch1x1): BasicConv2d(
#       (conv): Conv2d(1280, 320, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(320, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3_1): BasicConv2d(
#       (conv): Conv2d(1280, 384, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(384, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3_2a): BasicConv2d(
#       (conv): Conv2d(384, 384, kernel_size=(1, 3), stride=(1, 1), padding=(0, 1), bias=False)
#       (bn): BatchNorm2d(384, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3_2b): BasicConv2d(
#       (conv): Conv2d(384, 384, kernel_size=(3, 1), stride=(1, 1), padding=(1, 0), bias=False)
#       (bn): BatchNorm2d(384, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3dbl_1): BasicConv2d(
#       (conv): Conv2d(1280, 448, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(448, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3dbl_2): BasicConv2d(
#       (conv): Conv2d(448, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn): BatchNorm2d(384, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3dbl_3a): BasicConv2d(
#       (conv): Conv2d(384, 384, kernel_size=(1, 3), stride=(1, 1), padding=(0, 1), bias=False)
#       (bn): BatchNorm2d(384, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3dbl_3b): BasicConv2d(
#       (conv): Conv2d(384, 384, kernel_size=(3, 1), stride=(1, 1), padding=(1, 0), bias=False)
#       (bn): BatchNorm2d(384, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch_pool): BasicConv2d(
#       (conv): Conv2d(1280, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (my_Mixed_7c): InceptionE(
#     (branch1x1): BasicConv2d(
#       (conv): Conv2d(2048, 320, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(320, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3_1): BasicConv2d(
#       (conv): Conv2d(2048, 384, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(384, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3_2a): BasicConv2d(
#       (conv): Conv2d(384, 384, kernel_size=(1, 3), stride=(1, 1), padding=(0, 1), bias=False)
#       (bn): BatchNorm2d(384, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3_2b): BasicConv2d(
#       (conv): Conv2d(384, 384, kernel_size=(3, 1), stride=(1, 1), padding=(1, 0), bias=False)
#       (bn): BatchNorm2d(384, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3dbl_1): BasicConv2d(
#       (conv): Conv2d(2048, 448, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(448, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3dbl_2): BasicConv2d(
#       (conv): Conv2d(448, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn): BatchNorm2d(384, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3dbl_3a): BasicConv2d(
#       (conv): Conv2d(384, 384, kernel_size=(1, 3), stride=(1, 1), padding=(0, 1), bias=False)
#       (bn): BatchNorm2d(384, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3dbl_3b): BasicConv2d(
#       (conv): Conv2d(384, 384, kernel_size=(3, 1), stride=(1, 1), padding=(1, 0), bias=False)
#       (bn): BatchNorm2d(384, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch_pool): BasicConv2d(
#       (conv): Conv2d(2048, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#   (fc): Linear(in_features=2048, out_features=345, bias=True)
# )

# %%
from utils.AverageMeter import AverageMeter
from utils.accuracy import *

validation_acc = AverageMeter()

extracted_features = []

label = None
output = None
with torch.no_grad():
    for idx, (sketch, label) in enumerate(tqdm(feat_loader, ascii=True)):

        sketch = sketch.cuda()
        print(sketch.shape)
        label = label.cuda()

        output = net(sketch)
        output = output.squeeze()
        
        validation_acc.update(accuracy(net.fc(output), label, topk = (1,))[0].item(), sketch.size(0))
        extracted_features.append(output.detach().cpu().numpy())
#         print(output.shape)
#         break
# Out:
#   0%|          | 0/13 [00:00<?, ?it/s]
# torch.Size([64, 3, 299, 299])
#  15%|#5        | 2/13 [00:01<00:07,  1.51it/s]
# torch.Size([64, 3, 299, 299])
# torch.Size([64, 3, 299, 299])
#  31%|###       | 4/13 [00:01<00:02,  3.30it/s]
# torch.Size([64, 3, 299, 299])
# torch.Size([64, 3, 299, 299])
#  46%|####6     | 6/13 [00:02<00:01,  5.12it/s]
# torch.Size([64, 3, 299, 299])
# torch.Size([64, 3, 299, 299])
#  62%|######1   | 8/13 [00:02<00:00,  6.44it/s]
# torch.Size([64, 3, 299, 299])
# torch.Size([64, 3, 299, 299])
#  77%|#######6  | 10/13 [00:02<00:00,  7.42it/s]
# torch.Size([64, 3, 299, 299])
# torch.Size([64, 3, 299, 299])
#  92%|#########2| 12/13 [00:02<00:00,  7.99it/s]
# torch.Size([64, 3, 299, 299])
# torch.Size([32, 3, 299, 299])
# 100%|##########| 13/13 [00:02<00:00,  4.49it/s]

# %%
print(validation_acc.avg)
# Out:
# 91.375

# %%
feature_save_folder = os.path.join("/raid/xiaoyuz1/sketch_datasets/spg_features/cnn", "airplane")
if not os.path.exists(feature_save_folder):
    os.mkdir(feature_save_folder)

# %%
save_prefix = 0
feature_path = os.path.join(feature_save_folder, '{}.npy'.format(save_prefix))
image_name_path = os.path.join(feature_save_folder, '{}.txt'.format(save_prefix))

with open(image_name_path, "w+") as f:
    f.write("\n".join(feat_loader.dataset.sketch_urls))

with open(feature_path, 'wb') as f:
    np.save(f, np.vstack(extracted_features))

# %%
with open('./extract_cnn.sh', 'w+') as f:
    for file in os.listdir('/raid/xiaoyuz1/sketch_datasets/spg'):
        
#         if file in ['airplane',  'basket',  'butterfly',  'candle',   'drill',  'face']:
#             continue
        
#         for start,end in zip([0,200,400,600],[200,400,600,800]):
        fdr1 = os.path.join('/raid/xiaoyuz1/sketch_datasets/spg', file)
        fdr2 = os.path.join('/raid/xiaoyuz1/sketch_datasets/spg_features/cnn', file)
        line = "python extract_inception_features.py --folder {} --feature_save_folder {} --label {}\n".format(fdr1,fdr2,file)
        f.write(line)

# %%
# /home/xiaoyuz1/amazon_turk/extract_inception_features.py
