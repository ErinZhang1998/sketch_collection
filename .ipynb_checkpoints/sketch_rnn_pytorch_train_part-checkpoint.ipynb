# %%
import torch
import sys
sys.path.append("/home/xiaoyuz1/amazon_turk/Pytorch-Sketch-RNN")
import sketch_rnn as sr

import numpy as np
import matplotlib.pyplot as plt
import PIL
import pickle

import torch
import torch.nn as nn
from torch import optim
import torch.nn.functional as F

import torchvision.models as models
import os

import part_model as pm
from importlib import reload
import pickle
reload(pm)
reload(sr)
# Out:
# (9548,) <class 'numpy.ndarray'>
# (9548,) <class 'numpy.ndarray'>
# <module 'sketch_rnn' from '/home/xiaoyuz1/amazon_turk/Pytorch-Sketch-RNN/sketch_rnn.py'>

# %%
import ujson as json

import read_datasets as rd
import cv2
import pandas as pd


reload(rd)

# category_name = "pig"
# obj = json.load(open(
#     '/raid/xiaoyuz1/sketch_datasets/SketchX-PRIS-Dataset/Perceptual Grouping/{}.ndjson'.format(category_name), 
#     'r'))
# folder = '/raid/xiaoyuz1/sketch_datasets/spg'
# Out:
# <module 'read_datasets' from '/home/xiaoyuz1/amazon_turk/read_datasets.py'>

# %% [markdown]
# ### Mapping from body part labels to head part labels

# %%
dataset_mapping = {'angel': [[5], [0,1,2,3,4]],
    'butterfly': [[], []],
                   'ice_cream': [[1], [0]],
 'candle': [[0], [1,2]],
 'drill': [[1], [0]],
 'pineapple': [[1], [0]],
 'ambulance': [[1], [0]],
 'duck': [[1], [0,3]],
 'basket': [[1], [0]],
 'pig': [[5], [0,1,2,3,4]],
 'suitcase': [[1], [0]],
 'alarm_clock': [[], []],
 'flower': [[2], [0,1]],
 'house': [[1], [0]],
 'coffee_cup': [[], []],
 'bulldozer': [[], []],
 'calculator': [[], []],
 'face': [[], []],
 'campfire': [[], []],
 'airplane': [[], []],
 'backpack': [[], []],
 'ant': [[3], [0,1,2]],
 'crab': [[2], [0,1]],
 'apple': [[], []],
 'cactus': [[], []]}

dataset_mapping = {'angel': [[7], [0,1,2,3,4]]}

# %%
def show_these_sketches(category_name, png_indices, part_indices=[], show_title=False):
    obj = json.load(open(
    '/raid/xiaoyuz1/sketch_datasets/SketchX-PRIS-Dataset/Perceptual Grouping/{}.ndjson'.format(category_name), 
    'r'))
    all_bodies = []
    idx_used = []
    for idx, drawing_raw in enumerate(obj['train_data']):
        if idx not in png_indices:
            continue
        
        drawing_raw_np = np.asarray(drawing_raw)
        absolute_coord = rd.to_absolute(drawing_raw)
        stroke3_rendered = rd.absolutedata2stroke3(absolute_coord, label_selected=part_indices)
        all_bodies.append(stroke3_rendered)
        idx_used.append(idx)
    # print(idx_used)
    
    plt.figure(figsize = (30,30))
    index_plot = 0
    for index, part_data in enumerate(all_bodies):
        plt.subplot(15,15,index+1);
        batch_copy = np.copy(np.asarray(all_bodies[index]))
        if len(batch_copy) >= 5:
            
            batch_copy[:, 0] = np.cumsum(batch_copy[:,0], 0)
            batch_copy[:, 1] = np.cumsum(batch_copy[:,1], 0)

            strokes = np.split(batch_copy, np.where(batch_copy[:, 2] > 0)[0] + 1)
            for s in strokes:
                plt.plot(s[:,0], s[:,1], linewidth=2.0, c='black')

            
            canvas = plt.get_current_fig_manager().canvas
            canvas.draw()
        if show_title:
            plt.title(idx_used[index])
        plt.xlim(0,256)
        plt.ylim(256,0)
        
        plt.axis('off')

    plt.show()
    plt.close()

# %% [markdown]
# ### Process the selected cluster of wings

# %%
# txt_fname = "/home/xiaoyuz1/amazon_turk/wing_type.txt"
# with open(txt_fname, 'r') as f:
#     lines = f.readlines()
#     for line in lines:
#         if line == "\n":
#              type_indices.append([])
#         print(line)
#         line_chunks = line.split("\t")
#         line_chunks = [x.strip() for x in line_chunks]
#         line_parts = []
#         for x in line_chunks:
#             if x.startswith("Sketch"):
#                 # line_parts.append(x)
#                 for y in x.split(";"):
#                     y = y.strip()
#                     if y.startswith("Sketch"):
#                         idx = int(y.split(" ")[1])
#                         line_parts.append(idx)
#         type_indices[-1] += line_parts

def return_cluster_indices(res):
    cluster_indices = []
    for k,v in res.items():
        
        anno_idx = int(k.split("-")[0].split("_")[1])
        start_idx = 20 * (anno_idx-1)
        
        v = v.strip()
        for y in v.split(";"):
            y = y.strip()
            if y.startswith("Sketch"):
                sketch_idx = int(y.split(" ")[1])
                cluster_indices += [start_idx+sketch_idx-1]
    return cluster_indices

# %%
res1 = {"answer_1-7":"Sketch 4; Sketch 16; Sketch 19; ","answer_10-7":"Sketch 18; ","answer_12-7":"Sketch 5; ","answer_15-7":"Sketch 9; ","answer_17-7":"Sketch 7; ","answer_2-7":"Sketch 7; Sketch 19; ","answer_3-7":"Sketch 1; Sketch 6; Sketch 14; ","answer_4-7":"Sketch 15; ","answer_5-7":"Sketch 17; ","answer_7-7":"Sketch 3; ","answer_9-7":"Sketch 15; "}
res2 = {"answer_1-7":"Sketch 1; Sketch 6; ","answer_10-7":"Sketch 3; Sketch 12; ","answer_13-7":"Sketch 10; ","answer_14-7":"Sketch 17; ","answer_17-7":"Sketch 6; ","answer_18-7":"Sketch 4; ","answer_19-7":"Sketch 11; ","answer_2-7":"Sketch 13; ","answer_20-7":"Sketch 5; ","answer_3-7":"Sketch 2; Sketch 7; ","answer_4-7":"Sketch 9; Sketch 19; ","answer_6-7":"Sketch 8; ","answer_7-7":"Sketch 11; ","answer_8-7":"Sketch 12; "}
res3 = {"answer_1-7":"Sketch 3; ","answer_11-7":"Sketch 13; ","answer_15-7":"Sketch 17; Sketch 20; ","answer_16-7":"Sketch 3; Sketch 13; ","answer_18-7":"Sketch 15; ","answer_2-7":"Sketch 8; Sketch 13; ","answer_20-7":"Sketch 12; Sketch 15; Sketch 20; ","answer_3-7":"Sketch 15; ","answer_4-7":"Sketch 9; ","answer_5-7":"Sketch 9; Sketch 16; ","answer_6-7":"Sketch 13; ","answer_7-7":"Sketch 11; Sketch 17; ","answer_8-7":"Sketch 5; Sketch 11; ","answer_9-7":"Sketch 13; Sketch 20; "}
res4 = {"answer_1-7":"Sketch 5; Sketch 7; Sketch 11; Sketch 14; ","answer_11-7":"Sketch 8; Sketch 16; ","answer_12-7":"Sketch 17; Sketch 19; ","answer_13-7":"Sketch 20; ","answer_14-7":"Sketch 1; Sketch 7; ","answer_16-7":"Sketch 7; ","answer_17-7":"Sketch 9; Sketch 15; Sketch 17; ","answer_19-7":"Sketch 19; ","answer_2-7":"Sketch 7; Sketch 10; Sketch 16; ","answer_20-7":"Sketch 4; Sketch 9; Sketch 19; ","answer_3-7":"Sketch 1; Sketch 3; Sketch 6; Sketch 11; ","answer_4-7":"Sketch 15; ","answer_6-7":"Sketch 9; ","answer_7-7":"Sketch 8; Sketch 18; ","answer_9-7":"Sketch 1; Sketch 4; Sketch 10; Sketch 15; "}
res5 = {"answer_10-7":"Sketch 1; Sketch 5; Sketch 10; Sketch 14; ","answer_11-7":"Sketch 15; Sketch 16; Sketch 18; Sketch 20; ","answer_12-7":"Sketch 1; Sketch 11; ","answer_13-7":"Sketch 7; Sketch 19; ","answer_14-7":"Sketch 4; Sketch 5; Sketch 6; Sketch 15; ","answer_15-7":"Sketch 8; Sketch 12; ","answer_16-7":"Sketch 6; Sketch 16; ","answer_17-7":"Sketch 15; Sketch 17; ","answer_18-7":"Sketch 8; Sketch 17; ","answer_19-7":"Sketch 3; Sketch 5; Sketch 8; Sketch 19; ","answer_2-7":"Sketch 2; Sketch 3; Sketch 4; Sketch 9; Sketch 17; Sketch 18; ","answer_20-7":"Sketch 6; Sketch 16; Sketch 18; ","answer_3-7":"Sketch 1; Sketch 20; ","answer_4-7":"Sketch 11; ","answer_5-7":"Sketch 12; Sketch 15; Sketch 17; Sketch 19; ","answer_6-7":"Sketch 5; Sketch 6; Sketch 9; ","answer_8-7":"Sketch 4; Sketch 6; ","answer_9-7":"Sketch 4; Sketch 17; Sketch 19; "}
res6 = {"answer_1-7":"Sketch 10; ","answer_10-7":"Sketch 4; ","answer_11-7":"Sketch 1; ","answer_12-7":"Sketch 9; Sketch 20; ","answer_13-7":"Sketch 11; Sketch 13; ","answer_14-7":"Sketch 9; ","answer_16-7":"Sketch 1; ","answer_17-7":"Sketch 16; ","answer_18-7":"Sketch 18; Sketch 20; ","answer_19-7":"Sketch 4; Sketch 10; Sketch 18; ","answer_2-7":"Sketch 6; Sketch 11; ","answer_20-7":"Sketch 2; Sketch 8; ","answer_4-7":"Sketch 2; Sketch 12; Sketch 16; ","answer_5-7":"Sketch 1; Sketch 2; Sketch 7; ","answer_6-7":"Sketch 15; ","answer_7-7":"Sketch 15; Sketch 18; "}

all_wing_types = [res1,res2,res3,res4,res5,res6]

# %%
folder = "/raid/xiaoyuz1/sketch_datasets/spg_body/angel"
for i in range(6):
    with open(os.path.join(folder, "wing_type_{}.pickle".format(i+1)), 'wb') as f:
        pickle.dump(return_cluster_indices(all_wing_types[i]), f)

# %%
show_these_sketches("angel", return_cluster_indices(res1), [7])
show_these_sketches("angel", return_cluster_indices(res2), [7])

# %%
show_these_sketches("angel", return_cluster_indices(res3), [7])

# %%
show_these_sketches("angel", return_cluster_indices(res4), [7], show_title=True)

# ("angel", body_1, [5], show_title=True)

show_these_sketches("angel", return_cluster_indices(res5), [7], show_title=True)

# %%
show_these_sketches("angel", return_cluster_indices(res6), [7], )

# %% [markdown]
# ### Body Cluster (Crude)
# 0. oval
# 1. raindrop / rice
# 2. rectangular-ish
# 3. stick
# 4. with limbs
# 5. trapezoid
# 6. triangle
# 7. other

# %%
def return_cluster_indices(res, annotation_idx_to_list):
    cluster_indices = []
    for k,v in res.items():
        
        anno_idx = int(k.split("-")[0].split("_")[1])
        
        
        v = v.strip()
        for y in v.split(";"):
            y = y.strip()
            if y.startswith("Sketch"):
                sketch_idx = int(y.split(" ")[1])
                cluster_indices += [annotation_idx_to_list[anno_idx-1][sketch_idx-1]]
    return cluster_indices

# %%
triangle_res = {"answer_1-5":"Sketch 2; Sketch 3; Sketch 4; Sketch 5; Sketch 7; Sketch 8; Sketch 9; Sketch 14; Sketch 15; Sketch 16; Sketch 17; Sketch 19; ","answer_10-5":"Sketch 6; Sketch 8; Sketch 11; Sketch 12; Sketch 13; Sketch 15; Sketch 16; ","answer_2-5":"Sketch 1; Sketch 5; Sketch 6; Sketch 7; Sketch 8; Sketch 9; Sketch 10; Sketch 11; Sketch 12; Sketch 17; Sketch 19; Sketch 20; ","answer_3-5":"Sketch 1; Sketch 2; Sketch 3; Sketch 7; Sketch 11; Sketch 14; Sketch 15; Sketch 16; Sketch 20; ","answer_4-5":"Sketch 1; Sketch 3; Sketch 5; Sketch 6; Sketch 8; Sketch 9; Sketch 13; Sketch 14; Sketch 15; Sketch 16; Sketch 17; Sketch 19; ","answer_5-5":"Sketch 2; Sketch 7; Sketch 11; Sketch 13; Sketch 14; Sketch 17; Sketch 18; Sketch 20; ","answer_6-5":"Sketch 2; Sketch 3; Sketch 4; Sketch 6; Sketch 7; Sketch 8; Sketch 9; Sketch 11; Sketch 13; Sketch 17; Sketch 18; Sketch 20; ","answer_7-5":"Sketch 1; Sketch 4; Sketch 5; Sketch 8; Sketch 10; Sketch 12; Sketch 13; Sketch 17; ","answer_8-5":"Sketch 1; Sketch 2; Sketch 3; Sketch 13; Sketch 16; Sketch 18; Sketch 19; Sketch 20; ","answer_9-5":"Sketch 8; Sketch 13; Sketch 15; Sketch 16; Sketch 17; "}
with_head_res = {"answer_1-5":"Sketch 6; Sketch 18; ","answer_2-5":"Sketch 20; ","answer_3-5":"Sketch 19; ","answer_5-5":"Sketch 6; ","answer_7-5":"Sketch 6; Sketch 7; "}
trapezoid_res = {
    "answer_1-5":"Sketch 3; Sketch 9; Sketch 11; Sketch 13; Sketch 20; ", \
    "answer_10-5":"Sketch 1; Sketch 3; Sketch 4; Sketch 5; Sketch 7; Sketch 9; Sketch 10; Sketch 11; Sketch 13; Sketch 14; ","answer_2-5":"Sketch 2; Sketch 3; Sketch 4; Sketch 7; Sketch 10; Sketch 13; Sketch 14; Sketch 19; ", \
    "answer_3-5":"Sketch 4; Sketch 5; Sketch 6; Sketch 8; Sketch 9; Sketch 10; Sketch 12; Sketch 13; Sketch 17; Sketch 18; ","answer_4-5":"Sketch 1; Sketch 2; Sketch 3; Sketch 4; Sketch 5; Sketch 7; Sketch 10; Sketch 11; Sketch 12; ", \
    "answer_5-5":"Sketch 3; Sketch 8; Sketch 9; Sketch 10; Sketch 11; Sketch 12; Sketch 13; Sketch 16; Sketch 19; Sketch 20; ","answer_6-5":"Sketch 4; Sketch 5; Sketch 8; Sketch 9; Sketch 11; Sketch 13; Sketch 17; Sketch 18; Sketch 19; Sketch 20; ", \
    "answer_7-5":"Sketch 1; Sketch 2; Sketch 3; Sketch 4; Sketch 9; Sketch 13; Sketch 14; Sketch 16; Sketch 20; ","answer_8-5":"Sketch 1; Sketch 5; Sketch 6; Sketch 7; Sketch 12; Sketch 14; ","answer_9-5":"Sketch 2; Sketch 3; Sketch 5; Sketch 6; Sketch 10; Sketch 11; Sketch 12; Sketch 13; Sketch 15; Sketch 18; Sketch 19; Sketch 20; "}

other_res = {"answer_1-5":"Sketch 1; ","answer_2-5":"Sketch 12; Sketch 15; Sketch 18; ","answer_5-5":"Sketch 15; ","answer_6-5":"Sketch 14; ","answer_7-5":"Sketch 11; ","answer_8-5":"Sketch 9; ","answer_9-5":"Sketch 1; Sketch 2; Sketch 7; "}
stick_res = {"answer_1-5":"Sketch 12; ","answer_10-5":"Sketch 2; ","answer_5-5":"Sketch 1; Sketch 5; ","answer_6-5":"Sketch 1; Sketch 12; Sketch 15; Sketch 16; ","answer_7-5":"Sketch 18; ","answer_8-5":"Sketch 15; Sketch 17; ","answer_9-5":"Sketch 9; "}
oval_res = {"answer_5-5":"Sketch 4; "}
rectangle_res = {"answer_4-5":"Sketch 18; "}

import pickle
with open('/raid/xiaoyuz1/angel_body_unannotated.pkl', 'rb') as f:
    body_list = pickle.load(f)
print(len(body_list))

body_1 = return_cluster_indices(rectangle_res, body_list)
show_these_sketches("angel", body_1, [5], show_title=True)

# %%
'''
clustered_files = "/raid/xiaoyuz1/sketch_datasets/angel_clustered_files.txt"
lines = None
with open(clustered_files, 'r') as f:
    lines = f.readlines()
annotated_pngs = [int(x.strip().split(".")[0]) for x in list(filter(lambda x: len(x)>0, lines))]
annotated_groups = [[]]
end_idx = [94, 98, 91, 99, 78, 93, 97, 9]
for idx in annotated_pngs:
    annotated_groups[-1].append(idx)
    if idx in end_idx:
        annotated_groups.append([])

'''
annotated_pngs = []
annotated_pngs_d = {}
for file in os.listdir("/raid/xiaoyuz1/sketch_datasets/spg_body/angel"):
    if file.endswith(".pickle"):
        
        with open(os.path.join("/raid/xiaoyuz1/sketch_datasets/spg_body/angel", file), 'rb') as f:
            png_idx = pickle.load(f)
            
            annotated_pngs += list(png_idx)
            annotated_pngs_d[file.split(".")[0]] = png_idx

# un_annotated_pngs = list(filter(lambda x: x not in annotated_pngs, list(range(800))))
# with open('/raid/xiaoyuz1/sketch_datasets/spg_body/angel/not_rectangular_body.pickle', 'rb') as f:
#     un_annotated_pngs +=  pickle.load(f)
# un_annotated_pngs = np.sort(np.unique(un_annotated_pngs))

# %%
annotated_pngs_d['with_limbs_body']
# Out:
# [78, 230, 273, 299, 308, 612, 665, 724, 742, 268]

# %%
for k,v in annotated_pngs_d.items():
    print(k, len(v))
# Out:
# with_head_body 11
# oval_body 35
# with_limbs_body 10
# not_annotated_body 94
# wing_type_5 52
# other_body 66
# not_rectangular_body 61
# rectangular_body 55
# triangle_body 162
# wing_type_1 16
# stick_body 148
# wing_type_3 23
# trapezoid_body 219
# wing_type_2 18
# wing_type_6 28
# wing_type_4 34
# raindrop_body 30

# %%
for k,v in annotated_pngs_d.items():
    if(204 in v):
        print(k)
# Out:
# stick_body

# %%
show_these_sketches("angel", annotated_pngs_d['not_annotated_body'], [5], show_title=True)

# %%
show_these_sketches("angel", annotated_pngs_d['stick_body'], [], show_title=True)

# %%
show_these_sketches("angel", annotated_pngs_d['triangle_body'], [5], show_title=True)

# %%
show_these_sketches("angel", annotated_pngs_d['oval_body'], [], show_title=True)
show_these_sketches("angel", annotated_pngs_d['raindrop_body'], [], show_title=True)

# %%
idx_list = list(np.sort(np.unique(annotated_groups[4])))
remove_pngs = []
for ii in remove_pngs:
    if ii in idx_list:
        idx_list.remove(ii)

# %%
idx_list = list(annotated_pngs_d['stick_body'])
idx_list.remove(204)
with open('/raid/xiaoyuz1/sketch_datasets/spg_body/angel/stick_body.pickle', 'wb') as f:
    pickle.dump(idx_list, f)

# %%
with open('/raid/xiaoyuz1/sketch_datasets/spg_body/angel/with_limbs_body.pickle', 'rb') as f:
    idx_list2 = pickle.load(f)
show_these_sketches("angel", idx_list2, [5], show_title=False)
show_these_sketches("angel", idx_list2, [], show_title=False)

# %%
# [100, 101, 104]
show_these_sketches("angel", annotated_groups[3][:3], [5])
show_these_sketches("angel", annotated_groups[3][:3], [5,7])
show_these_sketches("angel", annotated_groups[3][:3], [1,2,3,4,5,7])
show_these_sketches("angel", annotated_groups[3][:3])

# %%
# idx_str = "102.png  144.png  17.png   1.png    251.png  270.png  27.png   329.png  366.png  387.png  432.png  461.png  481.png  593.png  646.png  703.png  715.png  757.png  94.png139.png  14.png   185.png  244.png  261.png  276.png  283.png  364.png  375.png  414.png  443.png  462.png  589.png  636.png  684.png  713.png  731.png  785.png"
# idx_list = [int(x.split(".")[0]) for x in list(filter(lambda x: len(x)>0, idx_str.split(" ")))]

# %%
folder = '/raid/xiaoyuz1/sketch_datasets/spg_body'

all_bodies = []
sketch_idx = []

# ! 
skipped = None

# for category_name, part_start_end in dataset_mapping.items():
for category_name in ["angel"]:
    part_start_end = dataset_mapping[category_name]
    
    print(category_name)
    
    rendered_idxs, _ = part_start_end
    if len(rendered_idxs) == 0:
        continue
    
    obj = json.load(open(
    '/raid/xiaoyuz1/sketch_datasets/SketchX-PRIS-Dataset/Perceptual Grouping/{}.ndjson'.format(category_name), 
    'r'))
    category_folder = os.path.join(folder, category_name)
    if not os.path.exists(category_folder):
        os.mkdir(category_folder)
    
    skipped = np.ones(len(obj['train_data'])).astype(bool)
    
    for idx, drawing_raw in enumerate(obj['train_data']):
        drawing_raw_np = np.asarray(drawing_raw)
        mask = np.zeros(len(drawing_raw)).astype(bool)
        for l in rendered_idxs:
            mask[drawing_raw_np[:,-1] == l] = True
        if np.sum(mask) < 5:
            skipped[idx] = False
            continue

#         image_data_all = rd.transform_spg_2_svg_png(drawing_raw)
#         plt.figure(figsize=(5,5))
#         plt.imshow(image_data_all)
#         plt.show()
        
        
#         png_path = os.path.join(category_folder, '{}.png'.format(idx))
#         image_data = rd.transform_spg_2_svg_png(drawing_raw, draw_color=False, label_selected = rendered_idxs)
#         plt.figure(figsize=(5,5))
#         plt.imshow(image_data)
#         plt.show()
        
        absolute_coord = rd.to_absolute(drawing_raw)
        # print(np.mean(np.asarray(absolute_coord)[:,:2], axis=0))
        stroke3_rendered = rd.absolutedata2stroke3(absolute_coord, label_selected=rendered_idxs)
            
#         stroke5 = rd.absolutedata2stroke5(absolute_coord, label_selected=rendered_idxs)
#         image_data_other = rd.transform_5_stroke_2_svg_png(stroke5, output_dim=(256,256), stroke_width=2)
#         plt.figure(figsize=(5,5))
#         plt.imshow(image_data_other)
#         print(image_data_other.shape)
#         plt.show()
        
        all_bodies.append(stroke3_rendered)
        sketch_idx.append((category_name, idx))

#         if idx > 10:
#             break
#     break
# Out:
# angel
# [111.9954659  125.62181919]
# [127.64985848 105.68679969]
# [112.15420875 126.24175084]
# [111.20988207 132.97283177]
# [134.46799723 127.30169893]
# [104.22744077 112.9823421 ]
# [130.57020737 112.41352892]
# [124.45217458 121.52915306]
# [ 97.37001372 129.22035129]
# [ 89.88866954 134.13612118]
# [124.13958281  92.5861321 ]
# [100.29716277 114.09706322]
# [113.09726444  83.5248227 ]
# [138.28636757  72.80050008]
# [115.31985185 105.3447724 ]
# [121.0005144  117.02491182]
# [119.94808673 107.56411197]
# [117.2002766   65.96566725]
# [ 98.84648465 140.02408436]
# [119.13953074 100.61191586]
# [107.88274226 132.05388362]
# [123.75792507 109.5129683 ]
# [ 85.24866474 105.05428596]
# [116.68118467 120.14292167]
# [121.80167082  79.95943816]
# [ 97.98686358 121.21038732]
# [118.12318229  91.66041217]
# [122.43720294 112.78230104]
# [123.75778894 120.17788945]
# [130.86384949 110.28992819]
# [102.39741613 109.43019114]
# [127.42994962  88.4717329 ]
# [122.9568516   71.67925101]
# ...

# %%
new_idx = np.cumsum(skipped, 0) -1

# %%
len(all_bodies)
# Out:
# 792

# %%
plt.figure(figsize = (30,30));

for index, part_data in enumerate(all_bodies[:400]):
    plt.subplot(20,20,index+1);
    batch_copy = np.copy(np.asarray(all_bodies[new_idx[index]]))
    batch_copy[:, 0] = np.cumsum(batch_copy[:,0], 0)
    batch_copy[:, 1] = np.cumsum(batch_copy[:,1], 0)

    strokes = np.split(batch_copy, np.where(batch_copy[:, 2] > 0)[0] + 1)
    for s in strokes:
        plt.plot(s[:,0], s[:,1], linewidth=2.0, c='black')

    plt.xlim(0,256)
    plt.ylim(256,0)
    canvas = plt.get_current_fig_manager().canvas
    canvas.draw()
    #
    plt.axis('off')

plt.show()
plt.close()

# %%
batch_copy = np.copy(np.asarray(all_bodies[new_idx[1]]))
batch_copy[:, 0] = np.cumsum(batch_copy[:,0], 0)
batch_copy[:, 1] = np.cumsum(batch_copy[:,1], 0)

x_max, y_max = np.max(batch_copy, axis=0)

batch_copy[:, 0] = batch_copy[:, 0] - mean_x
batch_copy[:, 1] = batch_copy[:, 1] - mean_y

strokes = np.split(batch_copy, np.where(batch_copy[:, 2] > 0)[0] + 1)
fig = plt.figure(figsize=(5,10))
ax1 = fig.add_subplot(211)
for s in strokes:
    plt.plot(s[:,0], s[:,1], linewidth=5.0, c='black')
print(np.mean(batch_copy[:,:2], axis=0))
# plt.xlim(0,256)
# plt.ylim(256,0)
plt.xlim(-128, 128)
plt.ylim(128,-128)
canvas = plt.get_current_fig_manager().canvas
canvas.draw()
#
# Out:
# [ 5.68434189e-15 -1.78425176e-14]

# %%
batch_copy = np.copy(np.asarray(all_bodies[new_idx[1]]))
batch_copy[:, 0] = np.cumsum(batch_copy[:,0], 0)
batch_copy[:, 1] = np.cumsum(batch_copy[:,1], 0)

strokes = np.split(batch_copy, np.where(batch_copy[:, 2] > 0)[0] + 1)
fig = plt.figure(figsize=(5,10))
ax1 = fig.add_subplot(211)
for s in strokes:
    plt.plot(25+s[:,0], 25+s[:,1], linewidth=5.0, c='black')

plt.xlim(0,256)
plt.ylim(256,0)
canvas = plt.get_current_fig_manager().canvas
canvas.draw()
#

# %%
def divide_list_ttv(total_length):
    
    num_train = int(total_length * 0.9)
    num_val = int(total_length * 0.05)
    num_test = total_length - num_train - num_val
    
    test_idx = np.random.choice(np.arange(total_length), num_test, replace=False)
    train_val = list(filter(lambda x : x not in test_idx, np.arange(total_length)))
    val_idx = np.random.choice(train_val, num_val, replace=False)
    train_idx = list(filter(lambda x : x not in val_idx, train_val))

#     train_data = [all_data[idx] for idx in train_idx]
#     val_data = [all_data[idx] for idx in val_idx]
#     test_data = [all_data[idx] for idx in test_idx]

    return train_idx, val_idx, test_idx

# %%
category_names = [x for (x,y) in sketch_idx]
category_idx = [y for (x,y) in sketch_idx]

# %%
all_train = []
all_val = []
all_test = []

t_idx, v_idx, te_idx = [],[],[]

for category_name in np.unique(category_names):
    mask = np.where(np.asarray(category_names) == category_name)[0]
    
    all_data = [all_bodies[d] for d in mask]
    t,v,te = divide_list_ttv(len(all_data))  
    
    all_train += [all_data[idx] for idx in t]
    all_val += [all_data[idx] for idx in v]
    all_test += [all_data[idx] for idx in te]
    
    t_idx += [sketch_idx[mask[d]] for d in t]
    v_idx += [sketch_idx[mask[d]] for d in v]
    te_idx += [sketch_idx[mask[d]] for d in te]

# %%
t_idx[4000]
# Out:
# ('crab', 458)

# %%
print(np.where((np.asarray(category_names)  == 'crab') * (np.asarray(category_idx)  == 458)))
all_train[4000]

# %%
all_bodies[10270]

# %%
all_train = np.asarray([np.asarray(a) for a in all_train])
all_val = np.asarray([np.asarray(a) for a in all_val])
all_test = np.asarray([np.asarray(a) for a in all_test])

t_idx, v_idx, te_idx = np.asarray(t_idx,dtype=object), np.asarray(v_idx,dtype=object), np.asarray(te_idx,dtype=object)

npz_path = os.path.join('/raid/xiaoyuz1/sketch_datasets/spg_train_2/npz', 'body.npz')
npz_path = os.path.join(folder, 'body.npz')
print("Saved at: ", npz_path)
np.savez(npz_path, train=all_train, valid=all_val, test=all_test)

npz_path = os.path.join(folder, 'body_idx.npz')
print("Saved at: ", npz_path)
np.savez(npz_path, train=t_idx, valid=v_idx, test=te_idx)
# Out:
# Saved at:  /raid/xiaoyuz1/sketch_datasets/spg_body/body.npz
# Saved at:  /raid/xiaoyuz1/sketch_datasets/spg_body/body_idx.npz

# %%
reload(sr)
# Out:
# (9548,) <class 'numpy.ndarray'>
# <module 'sketch_rnn' from '/home/xiaoyuz1/amazon_turk/Pytorch-Sketch-RNN/sketch_rnn.py'>

# %%
sr.hp.data_location
# Out:
# '/raid/xiaoyuz1/sketch_datasets/spg_body/body.npz'

# %%
info_path = '/raid/xiaoyuz1/sketch_datasets/spg_body/body_idx.npz'
data_path = '/raid/xiaoyuz1/sketch_datasets/spg_body/body.npz'

def draw_part(info_path,data_path):
    dataset_info = np.load(info_path, encoding='latin1', allow_pickle=True)
    for t in ['train', 'valid', 'test']:
    train_info = dataset_info['train']

# %%
dataset_info = \
    np.load('/raid/xiaoyuz1/sketch_datasets/spg_body/body_idx.npz', encoding='latin1', allow_pickle=True)
train_info = dataset_info['train']

hp = sr.HParams()
dataset = np.load(hp.data_location, encoding='latin1', allow_pickle=True)
orig_data = dataset['train']
orig_data, orig_kept = sr.purify(orig_data)
# orig_data = sr.normalize(orig_data)
scale_factor = sr.calculate_normalizing_scale_factor(orig_data)
print(scale_factor, sr.scale_factor)

data = sr.data
# data = sr.purify(data)
# data = sr.normalize(data)
# Nmax = max_size(data)
# Out:
# 11.889778 11.889778

# %%
# seq = np.copy(orig_data[318])
# print(seq)
# print(seq.shape[0] <= sr.hp.max_seq_length and seq.shape[0] > 10)
# seq = np.minimum(seq, 1000)
# print(seq)
# seq = np.maximum(seq, -1000)
# print(seq)
# seq = np.array(seq, dtype=np.float32)
# print(seq)

# %%
def make_singleton_batch(data, idx):
    batch_sequences = [data[idx]]
    strokes = []
    lengths = []
    indice = 0
    for seq in batch_sequences:
        len_seq = len(seq[:,0])
        new_seq = np.zeros((sr.Nmax,5))
        new_seq[:len_seq , :2] = seq[:,:2]
        new_seq[:len_seq-1 , 2] = 1 - seq[:-1,2]
        new_seq[:len_seq, 3] = seq[:,2]
        new_seq[(len_seq-1):, 4] = 1
        new_seq[len_seq-1, 2:4] = 0
        lengths.append(len(seq[:,0]))
        strokes.append(new_seq)
        indice += 1

    return strokes[0], lengths[0]

# %%
idx_test = 1000
L = train_info[:,0] == 'angel'

train_category, train_idx = train_info[idx_test]
print(train_category, train_idx)

part_start_end = dataset_mapping[train_category]
rendered_idxs, _ = part_start_end
# Out:
# angel 318

# %%
len(train_info), len(orig_kept)
# Out:
# (9548, 9548)

# %%
np.where(L)[0].shape
# Out:
# (714,)

# %%
train_category = "angel"
train_idx = 27

# %%
obj = json.load(open(
    '/raid/xiaoyuz1/sketch_datasets/SketchX-PRIS-Dataset/Perceptual Grouping/{}.ndjson'.format(train_category), 
'r'))
drawing_raw = obj['train_data'][int(train_idx)]
drawing_raw_np = np.asarray(drawing_raw)
image_data_all = rd.transform_spg_2_svg_png(
    drawing_raw, output_dim=(256,256), draw_color=False, label_selected=[], stroke_width=5,
)
plt.figure(figsize=(5,5))
plt.imshow(image_data_all)
plt.axis("off")
plt.show()


# image_data = rd.transform_spg_2_svg_png(drawing_raw, draw_color=False, label_selected = rendered_idxs)
# plt.figure(figsize=(5,5))
# plt.imshow(image_data)
# plt.show()

# %%
def denormalize(strokes):
    """Normalize entire dataset (delta_x, delta_y) by the scaling factor."""
    data = []
    
    for seq in strokes:
        seq[:, 0:2] *= scale_factor
        data.append(seq)
    return data

# %%
new_idx = np.cumsum(sr.kept_idx,0) -1
print(new_idx[idx_test-1], new_idx[idx_test])
idx_test_in_data = new_idx[idx_test]
print(idx_test_in_data)
# Out:
# 978 979
# 979

# %%
batch, lengths = make_singleton_batch(sr.data, idx_test_in_data)
batch_copy = np.copy(batch)
batch_copy = denormalize([batch_copy])[0]

# %%
batch_copy[:, 0] = np.cumsum(batch_copy[:,0], 0)
batch_copy[:, 1] = np.cumsum(batch_copy[:,1], 0)
batch_copy = batch_copy[:lengths]

# %%
strokes = np.split(batch_copy, np.where(batch_copy[:, 2] < 1)[0] + 1)
fig = plt.figure(figsize=(5,10))
ax1 = fig.add_subplot(211)
for s in strokes:
    plt.plot(s[:,0]+25, s[:,1]+25)

plt.xlim(0,256)
plt.ylim(256,0)
canvas = plt.get_current_fig_manager().canvas
canvas.draw()
# pil_image = PIL.Image.frombytes('RGB', canvas.get_width_height(), canvas.tostring_rgb())

ax1 = fig.add_subplot(212)
for s in strokes:
    plt.plot(s[:,0]+25, s[:,1]+25)

plt.xlim(0,256)
plt.ylim(256,0)
canvas = plt.get_current_fig_manager().canvas
canvas.draw()
pil_image = PIL.Image.frombytes('RGB', canvas.get_width_height(), canvas.tostring_rgb())

# %%
new_idx = np.cumsum(orig_kept,0) -1
print(new_idx[idx_test-1], new_idx[idx_test])
idx_test_in_data = new_idx[idx_test]
print(idx_test_in_data)


batch, lengths = make_singleton_batch(orig_data, idx_test_in_data)
batch_copy = np.copy(batch)
batch_copy[:, 0] = np.cumsum(batch[:,0], 0)
batch_copy[:, 1] = np.cumsum(batch[:,1], 0)
batch_copy = batch_copy[:lengths]

strokes = np.split(batch_copy, np.where(batch_copy[:, 2] < 1)[0] + 1)
fig = plt.figure(figsize=(5,5))
ax1 = fig.add_subplot(111)
for s in strokes:
    plt.plot(s[:,0], -s[:,1])

# plt.xlim(0,256)
# plt.ylim(256,0)
canvas = plt.get_current_fig_manager().canvas
canvas.draw()
pil_image = PIL.Image.frombytes('RGB', canvas.get_width_height(), canvas.tostring_rgb())
# Out:
# 978 979
# 979

# %%
PIL.Image.open('/raid/xiaoyuz1/sketch_datasets/spg_body/jpg/20000_output_9_.jpg')
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=500x1000 at 0x7F6C69EE9AF0>
